# %% [markdown]
# # Reinforcement Learning

# %% [markdown]
# * `submitted.py`: Your homework. Edit, and then submit to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
# * `mp11_notebook.ipynb`: This is a <a href="https://anaconda.org/anaconda/jupyter">Jupyter</a> notebook to help you debug.  You can completely ignore it if you want, although you might find that it gives you useful instructions.
# * `pong.py`: This is a program that plays Pong.  If called interactively, it will call the module `pong_display.py` to create a display, so that you can play.  If told to use a Q-learner, it will call your `submitted.py` to do Q-learning.
# * `tests/test_visible.py`: This file contains about half of the <a href="https://docs.python.org/3/library/unittest.html">unit tests</a> that Gradescope will run in order to grade your homework.  If you can get a perfect score on these tests, then you should also get a perfect score on the additional hidden tests that Gradescope uses.
# * `requirements.txt`: This tells you which python packages you need to have installed, in order to run `grade.py`.  You can install all of those packages by typing `pip install -r requirements.txt` or `pip3 install -r requirements.txt`.

# %% [markdown]
# ### Table of Contents
#
# 1. <a href="#section1">Playing Pong</a>
# 1. <a href="#section2">Creating a Q-Learner Object</a>
# 1. <a href="#section3">Epsilon-First Exploration</a>
# 1. <a href="#section4">Q-Learning</a>
# 1. <a href="#section5">Saving and Loading Your Q and N Tables</a>
# 1. <a href="#section6">Exploitation</a>
# 1. <a href="#section7">Acting</a>
# 1. <a href="#section8">Training</a>
# 1. <a href="#section9">Extra Credit</a>

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## Playing Pong

# %% [markdown]
# Pong was the <a href="https://en.wikipedia.org/wiki/Pong">first video game produced by Atari.</a>  It is a simple game, based on table tennis.  Here is a two-person version of the game: https://commons.wikimedia.org/wiki/File:Pong_Game_Test2.gif
#
# We will be playing a one-person version of the game:
#
# * When the ball hits the top, bottom, or left wall of the playing field, it bounces.
# * The right end of the playing field is open, except for the paddle.  If the ball hits the paddle, it bounces, and the player's score increments by one.  If the ball hits the open space, the game is over; the score resets to zero, and a new game begins.
#
# The game is pretty simple, but in order to get a better feeling for it, you may want to try playing it yourself.  Use the up arrow to move the paddle upward, and the down arrow to move the paddle downward.  See how high you can make your score:

# %%
# !python3 pong.py
# Out:
# pygame 2.2.0 (SDL 2.0.22, Python 3.9.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Once you figure out how to use the arrow keys to control your paddle, we hope you will find that the game is not too hard for a human to play.  However, for a computer, it's difficult to know: where should the paddle be moved at each time step?  In order to see how difficult it is for a computer to play, let's ask the "random" player to play the game.
#
# **WARNING:** The following line will open a pygame window.  The pygame window will be hidden by this window -- in order to see it, you will need to minimize this window.  The pygame window will consume a lot of CPU time just waiting for the processor, so in order to kill it, you will need to come back to this window, click on the block below, then click the Jupyter "stop" button (the square button at the top of this window) in order to stop processing.

# %%
# !python3 pong.py --player random
# Out:
# pygame 2.2.0 (SDL 2.0.22, Python 3.9.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Completed 0 games, 1 rewards, 255 frames, score 0, max score 0
# Completed 1 games, 2 rewards, 436 frames, score 0, max score 0
# Completed 2 games, 3 rewards, 644 frames, score 0, max score 0
# Completed 3 games, 4 rewards, 825 frames, score 0, max score 0
# Completed 4 games, 5 rewards, 1033 frames, score 0, max score 0
# Completed 5 games, 6 rewards, 1287 frames, score 0, max score 0
# Completed 6 games, 8 rewards, 1784 frames, score 1, max score 1
# Completed 7 games, 9 rewards, 1965 frames, score 0, max score 1
# Completed 8 games, 10 rewards, 2173 frames, score 0, max score 1
# Completed 9 games, 11 rewards, 2354 frames, score 0, max score 1
# Completed 10 games, 12 rewards, 2562 frames, score 0, max score 1
# Completed 11 games, 13 rewards, 2816 frames, score 0, max score 1
# Completed 12 games, 14 rewards, 3070 frames, score 0, max score 1

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## Creating a Q-Learner Object

# %% [markdown]
# The first thing you will do is to create a `q_learner` object that can store your learned Q table and your N table (table of exploration counts).
#
# Like any other object-oriented language, python permits you to create new object classes in order to store data that will be needed from time to time.  If you are not already very, very familiar with python classes, you might want to study the python class tutorial: https://docs.python.org/3/tutorial/classes.html
#
# Like any other object in python, a `q_learner` object is created by calling its name as a function, e.g., `my_q_learner=submitted.q_learner()`.  Doing so calls the function `submitted.q_learner.__init__()`.  Let's look at the docstring to see what it should do.

# %%
import submitted, importlib
importlib.reload(submitted)
help(submitted.q_learner.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst, state_cardinality)
#     Create a new q_learner object.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a Q table and an N table.
#     Q[...state..., ...action...] = expected utility of state/action pair.
#     N[...state..., ...action...] = # times state/action has been explored.
#     Both are initialized to all zeros.
#     Up to you: how will you encode the state and action in order to
#     define these two lookup tables?  The state will be a list of 5 integers,
#     such that 0 <= state[i] < state_cardinality[i] for 0 <= i < 5.
#     The action will be either -1, 0, or 1.
#     It is up to you to decide how to convert an input state and action
#     into indices that you can use to access your stored Q and N tables.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#     state_cardinality (list) - cardinality of each of the quantized state variables
#
#     @return:
#     None

# %% [markdown]
# Write your `__init__` function to meet the requirements specified in the docstring.  Once you have completed it, the following code should run without errors:

# %%
importlib.reload(submitted)

q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])

print(q_learner)
# Out:
# <submitted.q_learner object at 0x12dfbd970>

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ## Epsilon-First Exploration

# %% [markdown]
# In order to manage the exploration/exploitation tradeoff, we will be using both "epsilon-first" and "epsilon-greedy" (https://en.wikipedia.org/wiki/Multi-armed_bandit#Semi-uniform_strategies).
#
# The epsilon-first strategy explores every state/action pair at least `nfirst` times before it ever starts to exploit any strategy.  Your `q_learner` should have a table to keep track of how many times it has explored a state/action pair prior to the start of any exploitation.  The method for storing that table is up to you; in order to have some standardized API, therefore, you need to write a method called `report_exploration_counts` that returns a list of the three exploration counts for a given state.

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_exploration_counts)
# Out:
# Help on function report_exploration_counts in module submitted:
#
# report_exploration_counts(self, state)
#     Check to see how many times each action has been explored in this state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     explored_count (array of 3 ints):
#       number of times that each action has been explored from this state.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# Write `report_exploration_counts` so that it returns a list or array for any given state.  Test your code with the following:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('This is how many times state [0,0,0,0,0] has been explored so far:')
print(q_learner.report_exploration_counts([0,0,0,0,0]))
print('This is how many times state [9,9,1,1,9] has been explored so far:')
print(q_learner.report_exploration_counts([9,9,1,1,9]))
# Out:
# This is how many times state [0,0,0,0,0] has been explored so far:
# [0. 0. 0.]
# This is how many times state [9,9,1,1,9] has been explored so far:
# [0. 0. 0.]

# %% [markdown]
# When your learner first starts learning, it will call the function `choose_unexplored_action` to choose an unexplored action.  This function should choose a function uniformly at random from the set of unexplored actions in a given state, if there are any:

# %%
importlib.reload(submitted)
help(submitted.q_learner.choose_unexplored_action)
# Out:
# Help on function choose_unexplored_action in module submitted:
#
# choose_unexplored_action(self, state)
#     Choose an action that has been explored less than nfirst times.
#     If many actions are underexplored, you should choose uniformly
#     from among those actions; don't just choose the first one all
#     the time.
#
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar): either -1, or 0, or 1, or None
#       If all actions have been explored at least n_explore times, return None.
#       Otherwise, choose one uniformly at random from those w/count less than n_explore.
#       When you choose an action, you should increment its count in your counter table.

# %% [markdown]
# If this has been written correctly, the following block should generate a random sequence of actions.  If the next block produces the same action 5 times in a row, that is the wrong result, and the result would be that your code does not pass the autograder.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: 0
# Next action: 0
# Next action: 1
# Next action: 1
# Next action: -1

# %% [markdown]
# After all three actions have been explored `nfirst` times, the function `choose_unexplored_action` should return `None`, as shown here:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,1,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: -1
# Next action: 1
# Next action: 0
# Next action: None

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## Q-Learning

# %% [markdown]
# The reinforcement learning we are implementing is called Q-learning (https://en.wikipedia.org/wiki/Q-learning).
#
# Q-learning keeps a table $Q[s,a]$ that specifies the expected utility of action $a$ in state $s$.  The organization of this table is up to you.  In order to have a standard API, the first thing you should implement is a function `report_q` with the following docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_q)
# Out:
# Help on function report_q in module submitted:
#
# report_q(self, state)
#     Report the current Q values for the given state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q (array of 3 floats):
#       reward plus expected future utility of each of the three actions.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# When your `q_learner` is first initialized, the value of $Q[state,action]$ should be zero for all state/action pairs, thus the `report_q` function should return lists of zeros:

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Q[0,0,0,0,0] is now:',q_learner.report_q([0,0,0,0,0]))
print('Q[9,9,1,1,9] is now:',q_learner.report_q([9,9,1,1,9]))
# Out:
# Q[0,0,0,0,0] is now: [0. 0. 0.]
# Q[9,9,1,1,9] is now: [0. 0. 0.]

# %% [markdown]
# There are actually many different Q-learning algorithms available, but when people refer to Q-learning with no modifier, they usually mean the time-difference (TD) algorithm.  For example, this is the algorithm that's described on the wikipedia page (https://en.wikipedia.org/wiki/Q-learning).  This is the algorithm you will implement for this MP.
#
# In supervised machine learning, the learner tries to imitate a reference label.  In reinforcement learning, there is no reference label.  Q-learning replaces the reference label with a "local Q" value, which is the utility that was obtained by performing action $a$ in state $s$ one time.  It is usually calculated like this:
#
# $$Q_{local}(s_t,a_t) = r_t + \gamma\max_{a_{t+1}}Q(s_{t+1},a_{t+1})$$
#
# where $r_t$ is the reward that was achieved by performing action $a_t$ in state $s_t$, $s_{t+1}$ is the state into which the game transitioned, and $a_{t+1}$ is one of the actions that could be performed in that state.  $Q_{local}$ is computed by your `q_local` function, which has this docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.q_local)
# Out:
# Help on function q_local in module submitted:
#
# q_local(self, reward, newstate)
#     The update to Q estimated from a single step of game play:
#     reward plus gamma times the max of Q[newstate, ...].
#
#     @param:
#     reward (scalar float): the reward achieved from the current step of game play.
#     newstate (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q_local (scalar float): the local value of Q

# %% [markdown]
# Initially, `q_local` should just return the given reward, because initially, all Q values are 0:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,10,10])
print('Q_local(6.25,[9,9,1,1,9]) is currently:',q_learner.q_local(6.25,[9,9,1,1,9]))
# Out:
# Q_local(6.25,[9,9,1,1,9]) is currently: 6.25

# %% [markdown]
# Now you can use `q_learner.q_local` as the target for `q_learner.learn`.  The basic algorithm is
#
# $$Q(s,a) = Q(s,a) + \alpha (Q_{local}(s,a)-Q(s,a))$$
#
# Here is the docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Update the internal Q-table on the basis of an observed
#     state, action, reward, newstate sequence.
#
#     @params:
#     state: a list of 5 numbers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle.
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 numbers, in the same format as state
#
#     @return:
#     None

# %% [markdown]
# The following block checks a sequence of Q updates:
#
# 1. First, $Q([9,9,1,1,9],-1)$ is updated.  Since all Q values start at zero, it will be updated to just have a value equal to $\alpha$ (0.05) times the given reward (6.25) for a total value of 0.3125.
# 1. When we print out $Q([9,9,1,1,9],:)$, we see that one of the elements has been updated.
# 1. Next, update $Q([9,9,1,1,8],1)$ with a given reward, and with $[9,9,1,1,9]$ as the given next state.  Since $Q([9,9,1,1,9],-1)$ is larger than zero, the next-state Q-value should be multiplied by $\gamma$ (0.99) and added to the reward (3.1), then multiplied by $\alpha$, giving a total value of 0.17046875.
# 1. The resulting Q-value is reported.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q[9,9,1,1,9] is now',q_learner.report_q([9,9,1,1,9]))
q_learner.learn([9,9,1,1,8],1,3.1,[9,9,1,1,9])
print('Q[9,9,1,1,8] is now',q_learner.report_q([9,9,1,1,8]))
# Out:
# Q[9,9,1,1,9] is now [0.3125 0.     0.    ]
# Q[9,9,1,1,8] is now [0.         0.         0.17046875]

# %% [markdown]
# <a id='section5'></a>

# %% [markdown]
# ## Saving and Loading your Q and N Tables

# %% [markdown]
# After you've spent a long time training your `q_learner`, you will want to save your Q and N tables so that you can reload them later.  The format of Q and N is up to you, therefore it's also up to you to write the `save` and `load` functions.  Here are the docstrings:

# %%
importlib.reload(submitted)
help(submitted.q_learner.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your Q and N tables to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.  We recommend numpy.savez,
#     but you can use something else if you prefer.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
importlib.reload(submitted)
help(submitted.q_learner.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load the Q and N tables from a file.
#     This should load from whatever file format your save function
#     used.  We recommend numpy.load, but you can use something
#     else if you prefer.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# These functions can be tested by doing one step of training one `q_learner`, then saving its results, then loading them into another `q_learner`:

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner1.choose_unexplored_action([9,9,1,1,9]))
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('N1[9,9,1,1,8] is now',q_learner1.report_exploration_counts([9,9,1,1,9]))
print('Q1[9,9,1,1,8] is now',q_learner1.report_q([9,9,1,1,9]))
q_learner1.save('test.npz')

q_learner2 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('N2[9,9,1,1,8] starts out as',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] starts out as',q_learner2.report_q([9,9,1,1,9]))
q_learner2.load('test.npz')
print('N2[9,9,1,1,8] is now',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] is now',q_learner2.report_q([9,9,1,1,9]))
# Out:
# Next action: -1
# N1[9,9,1,1,8] is now [1. 0. 0.]
# Q1[9,9,1,1,8] is now [0.3125 0.     0.    ]
# N2[9,9,1,1,8] starts out as [0. 0. 0.]
# Q2[9,9,1,1,8] starts out as [0. 0. 0.]
# N2[9,9,1,1,8] is now [1. 0. 0.]
# Q2[9,9,1,1,8] is now [0.3125 0.     0.    ]

# %% [markdown]
# <a id='section6'></a>

# %% [markdown]
# ## Exploitation

# %% [markdown]
# A reinforcement learner always has to trade off between exploration (choosing an action at random) versus exploitation (choosing the action with the maximum expected utility).  Before we worry about that tradeoff, though, let's first make sure that exploitation works.

# %%
importlib.reload(submitted)
help(submitted.q_learner.exploit)
# Out:
# Help on function exploit in module submitted:
#
# exploit(self, state)
#     Return the action that has the highest Q-value for the current state, and its Q-value.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar int): either -1, or 0, or 1.
#       The action that has the highest Q-value.  Ties can be broken any way you want.
#     Q (scalar float):
#       The Q-value of the selected action

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q1[9,9,1,1,9] is now',q_learner1.report_q([9,9,1,1,9]))
print('The best action and Q from state [9,9,1,1,9] are',q_learner1.exploit([9,9,1,1,9]))
# Out:
# Q1[9,9,1,1,9] is now [0.3125 0.     0.    ]
# The best action and Q from state [9,9,1,1,9] are (-1, 0.3125)

# %% [markdown]
# <a id='section7'></a>

# %% [markdown]
# ## Acting

# %% [markdown]
# When your learner decides which action to perform, it should trade off exploration vs. exploitation using both the epsilon-first and the epsilon-greedy strategies:
# 1. If there is any action that has been explored fewer than `nfirst` times, then choose one of those actions at random.  Otherwise...
# 1. With probability `epsilon`, choose an action at random.  Otherwise...
# 1. Exploit.

# %%
importlib.reload(submitted)
help(submitted.q_learner.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     If any action has been taken less than nfirst times, then choose one of those
#     actions, uniformly at random.
#     Otherwise, with probability epsilon, choose an action uniformly at random.
#     Otherwise, choose the action with the best Q(state,action).
#
#     @params:
#     state: a list of 5 integers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %% [markdown]
# In order to test all three types of action (epsilon-first exploration, epsilon-greedy exploration, and exploitation), let's create a learner with `nfirst=1` and `epsilon=0.25`, and set it so that the best action from state `[9,9,1,1,9]` is `-1`.  With these settings, a sequence of calls to `q_learner.act` should produce the following sequence of actions:
#
# 1. The first three actions should include each possible action once.
# 1. After the first three actions, 3/4 of the remaining actions should be `-1`.  The remaining 1/4 should be randomly chosen.

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.25,0.99,1,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
# Out:
# An epsilon-first action: 1
# An epsilon-first action: -1
# An epsilon-first action: 0
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: 0
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1

# %% [markdown]
# <a id='section8'></a>

# %% [markdown]
# ## Training

# %% [markdown]
# Now that all of your components work, you can try training your algorithm.  Do this by giving your `q_learner` as a player to a new `pong.PongGame` object.  Set `visibility=False` so that the `PongGame` doesn't create a new window.

# %%
import pong, importlib, submitted
importlib.reload(pong)
help(pong.PongGame.__init__)
# Out:
# Help on function __init__ in module pong:
#
# __init__(self, ball_speed=4, paddle_speed=8, learner=None, visible=True, state_quantization=[10, 10, 2, 2, 10])
#     Create a new pong game, with a specified player.
#
#     @params:
#     ball_speed (scalar int) - average ball speed in pixels/frame
#     paddle_speed (scalar int) - paddle moves 0, +paddle_speed, or -paddle_speed
#     learner - can be None if the player is human.  If not None, should be an
#       object of type random_learner, submitted.q_learner, or submitted.deep_q.
#     visible (bool) - should this game have an attached pygame window?
#     state_quantization (list) - if not None, state variables are quantized
#       into integers of these cardinalities before being passed to the learner.

# %% [markdown]
# As you can see, we should set `visibility=False` so that the `PongGame` doesn't create a new window.  We should also make sure that the PongGame uses the same state quantization as the learner.

# %%
importlib.reload(pong)
importlib.reload(submitted)
state_quantization = [10,10,2,2,10]
q_learner=submitted.q_learner(0.05,0.05,0.99,5,state_quantization)

pong_game = pong.PongGame(learner=q_learner, visible=False, state_quantization=state_quantization)
print(pong_game)
# Out:
# <pong.PongGame object at 0x1095dadc0>

# %% [markdown]
# In order to train our learner, we want it to play the game many times.  To do that we use the PongGame.run function:

# %%
help(pong_game.run)
# Out:
# Help on method run in module pong:
#
# run(m_rewards=inf, m_games=inf, m_frames=inf, states=[]) method of pong.PongGame instance
#     Run the game.
#     @param
#     m_frames (scalar int): maximum number of frames to be played
#     m_rewards (scalar int): maximum number of rewards earned (+ or -)
#     m_games (scalar int): maximum number of games
#     states (list): list of states whose Q-values should be returned
#        each state is a list of 5 ints: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#        and the y-position of the paddle, all quantized.
#        0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#
#     @return
#     scores (list): list of scores of all completed games
#
#     The following will be returned only if the player is q_learning or deep_q.
#     New elements will be added to these lists once/frame if m_frames is specified,
#     else once/reward if m_rewards is specified, else once/game:
#       q_achieved (list): list of the q-values of the moves that were taken
#       q_states (list): list of the q-values of requested states

# %% [markdown]
# In order to make sure our learner is learning, let's tell `pong_game.run` to output all 3 Q-values of all of the 4000 states in every time step.
#
# To make sure that's not an outrageous amount of data, let's tell it to only output the Q values once/reward, and ask it to only collect 5000 rewards:

# %%
states = [[x,y,vx,vy,py] for x in range(10) for y in range(10) for vx in range(2) for vy in range(2) for py in range(10) ]

scores, q_achieved, q_states = pong_game.run(m_rewards=500, states=states)

print('The number of games played was',len(scores))
print('The number of rewards was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 2 rewards, 591 frames, score 1, max score 1
# Completed 1 games, 3 rewards, 799 frames, score 0, max score 1
# Completed 2 games, 4 rewards, 1007 frames, score 0, max score 1
# Completed 3 games, 5 rewards, 1261 frames, score 0, max score 1
# Completed 4 games, 6 rewards, 1469 frames, score 0, max score 1
# Completed 5 games, 7 rewards, 1677 frames, score 0, max score 1
# Completed 6 games, 8 rewards, 1931 frames, score 0, max score 1
# Completed 7 games, 9 rewards, 2139 frames, score 0, max score 1
# Completed 8 games, 11 rewards, 2491 frames, score 1, max score 1
# Completed 9 games, 12 rewards, 2745 frames, score 0, max score 1
# Completed 10 games, 14 rewards, 3335 frames, score 1, max score 1
# Completed 11 games, 18 rewards, 4108 frames, score 3, max score 3
# Completed 12 games, 19 rewards, 4362 frames, score 0, max score 3
# Completed 13 games, 24 rewards, 5291 frames, score 4, max score 4
# Completed 14 games, 27 rewards, 6004 frames, score 2, max score 4
# Completed 15 games, 29 rewards, 6620 frames, score 1, max score 4
# Completed 16 games, 31 rewards, 7117 frames, score 1, max score 4
# Completed 17 games, 33 rewards, 7531 frames, score 1, max score 4
# Completed 18 games, 34 rewards, 7785 frames, score 0, max score 4
# Completed 19 games, 35 rewards, 7993 frames, score 0, max score 4
# Completed 20 games, 36 rewards, 8201 frames, score 0, max score 4
# Completed 21 games, 37 rewards, 8409 frames, score 0, max score 4
# Completed 22 games, 39 rewards, 8792 frames, score 1, max score 4
# Completed 23 games, 40 rewards, 8973 frames, score 0, max score 4
# Completed 24 games, 42 rewards, 9524 frames, score 1, max score 4
# Completed 25 games, 43 rewards, 9778 frames, score 0, max score 4
# Completed 26 games, 44 rewards, 9959 frames, score 0, max score 4
# Completed 27 games, 45 rewards, 10213 frames, score 0, max score 4
# Completed 28 games, 46 rewards, 10394 frames, score 0, max score 4
# Completed 29 games, 49 rewards, 11034 frames, score 2, max score 4
# Completed 30 games, 50 rewards, 11215 frames, score 0, max score 4
# Completed 31 games, 51 rewards, 11396 frames, score 0, max score 4
# Completed 32 games, 52 rewards, 11604 frames, score 0, max score 4
# Completed 33 games, 53 rewards, 11858 frames, score 0, max score 4
# Completed 34 games, 57 rewards, 12638 frames, score 3, max score 4
# Completed 35 games, 58 rewards, 12819 frames, score 0, max score 4
# Completed 36 games, 59 rewards, 13027 frames, score 0, max score 4
# Completed 37 games, 60 rewards, 13281 frames, score 0, max score 4
# Completed 38 games, 61 rewards, 13462 frames, score 0, max score 4
# Completed 39 games, 63 rewards, 13996 frames, score 1, max score 4
# Completed 40 games, 65 rewards, 14484 frames, score 1, max score 4
# Completed 41 games, 66 rewards, 14738 frames, score 0, max score 4
# Completed 42 games, 69 rewards, 15218 frames, score 2, max score 4
# Completed 43 games, 70 rewards, 15472 frames, score 0, max score 4
# Completed 44 games, 71 rewards, 15680 frames, score 0, max score 4
# Completed 45 games, 72 rewards, 15888 frames, score 0, max score 4
# Completed 46 games, 73 rewards, 16096 frames, score 0, max score 4
# Completed 47 games, 74 rewards, 16304 frames, score 0, max score 4
# Completed 48 games, 75 rewards, 16485 frames, score 0, max score 4
# Completed 49 games, 77 rewards, 16890 frames, score 1, max score 4
# Completed 50 games, 78 rewards, 17098 frames, score 0, max score 4
# Completed 51 games, 79 rewards, 17306 frames, score 0, max score 4
# Completed 52 games, 80 rewards, 17514 frames, score 0, max score 4
# Completed 53 games, 81 rewards, 17768 frames, score 0, max score 4
# Completed 54 games, 82 rewards, 17976 frames, score 0, max score 4
# Completed 55 games, 83 rewards, 18184 frames, score 0, max score 4
# Completed 56 games, 84 rewards, 18438 frames, score 0, max score 4
# Completed 57 games, 86 rewards, 18972 frames, score 1, max score 4
# Completed 58 games, 87 rewards, 19153 frames, score 0, max score 4
# Completed 59 games, 88 rewards, 19361 frames, score 0, max score 4
# Completed 60 games, 90 rewards, 19785 frames, score 1, max score 4
# Completed 61 games, 91 rewards, 19966 frames, score 0, max score 4
# Completed 62 games, 92 rewards, 20220 frames, score 0, max score 4
# Completed 63 games, 95 rewards, 20880 frames, score 2, max score 4
# Completed 64 games, 96 rewards, 21061 frames, score 0, max score 4
# Completed 65 games, 97 rewards, 21269 frames, score 0, max score 4
# Completed 66 games, 98 rewards, 21450 frames, score 0, max score 4
# Completed 67 games, 99 rewards, 21658 frames, score 0, max score 4
# Completed 68 games, 101 rewards, 22064 frames, score 1, max score 4
# Completed 69 games, 102 rewards, 22245 frames, score 0, max score 4
# Completed 70 games, 103 rewards, 22499 frames, score 0, max score 4
# Completed 71 games, 104 rewards, 22680 frames, score 0, max score 4
# Completed 72 games, 105 rewards, 22934 frames, score 0, max score 4
# Completed 73 games, 106 rewards, 23115 frames, score 0, max score 4
# Completed 74 games, 107 rewards, 23296 frames, score 0, max score 4
# Completed 75 games, 108 rewards, 23504 frames, score 0, max score 4
# Completed 76 games, 109 rewards, 23758 frames, score 0, max score 4
# Completed 77 games, 110 rewards, 23966 frames, score 0, max score 4
# Completed 78 games, 111 rewards, 24174 frames, score 0, max score 4
# Completed 79 games, 113 rewards, 24561 frames, score 1, max score 4
# Completed 80 games, 114 rewards, 24769 frames, score 0, max score 4
# Completed 81 games, 115 rewards, 24950 frames, score 0, max score 4
# Completed 82 games, 117 rewards, 25333 frames, score 1, max score 4
# Completed 83 games, 119 rewards, 25749 frames, score 1, max score 4
# Completed 84 games, 121 rewards, 26209 frames, score 1, max score 4
# Completed 85 games, 122 rewards, 26417 frames, score 0, max score 4
# Completed 86 games, 124 rewards, 26769 frames, score 1, max score 4
# Completed 87 games, 126 rewards, 27206 frames, score 1, max score 4
# Completed 88 games, 127 rewards, 27414 frames, score 0, max score 4
# Completed 89 games, 128 rewards, 27595 frames, score 0, max score 4
# Completed 90 games, 129 rewards, 27776 frames, score 0, max score 4
# Completed 91 games, 131 rewards, 28378 frames, score 1, max score 4
# Completed 92 games, 132 rewards, 28559 frames, score 0, max score 4
# Completed 93 games, 133 rewards, 28740 frames, score 0, max score 4
# Completed 94 games, 134 rewards, 28994 frames, score 0, max score 4
# Completed 95 games, 135 rewards, 29175 frames, score 0, max score 4
# Completed 96 games, 137 rewards, 29837 frames, score 1, max score 4
# Completed 97 games, 138 rewards, 30091 frames, score 0, max score 4
# Completed 98 games, 139 rewards, 30299 frames, score 0, max score 4
# Completed 99 games, 141 rewards, 30753 frames, score 1, max score 4
# Completed 100 games, 142 rewards, 31007 frames, score 0, max score 4
# Completed 101 games, 144 rewards, 31467 frames, score 1, max score 4
# Completed 102 games, 145 rewards, 31721 frames, score 0, max score 4
# Completed 103 games, 146 rewards, 31929 frames, score 0, max score 4
# Completed 104 games, 147 rewards, 32137 frames, score 0, max score 4
# Completed 105 games, 149 rewards, 32543 frames, score 1, max score 4
# Completed 106 games, 150 rewards, 32751 frames, score 0, max score 4
# Completed 107 games, 151 rewards, 33005 frames, score 0, max score 4
# Completed 108 games, 152 rewards, 33186 frames, score 0, max score 4
# Completed 109 games, 153 rewards, 33440 frames, score 0, max score 4
# Completed 110 games, 154 rewards, 33694 frames, score 0, max score 4
# Completed 111 games, 155 rewards, 33902 frames, score 0, max score 4
# Completed 112 games, 156 rewards, 34083 frames, score 0, max score 4
# Completed 113 games, 157 rewards, 34264 frames, score 0, max score 4
# Completed 114 games, 158 rewards, 34518 frames, score 0, max score 4
# Completed 115 games, 160 rewards, 35437 frames, score 1, max score 4
# Completed 116 games, 161 rewards, 35618 frames, score 0, max score 4
# Completed 117 games, 162 rewards, 35826 frames, score 0, max score 4
# Completed 118 games, 163 rewards, 36080 frames, score 0, max score 4
# Completed 119 games, 164 rewards, 36261 frames, score 0, max score 4
# Completed 120 games, 165 rewards, 36442 frames, score 0, max score 4
# Completed 121 games, 166 rewards, 36623 frames, score 0, max score 4
# Completed 122 games, 168 rewards, 37213 frames, score 1, max score 4
# Completed 123 games, 169 rewards, 37467 frames, score 0, max score 4
# Completed 124 games, 170 rewards, 37648 frames, score 0, max score 4
# Completed 125 games, 171 rewards, 37856 frames, score 0, max score 4
# Completed 126 games, 172 rewards, 38110 frames, score 0, max score 4
# Completed 127 games, 173 rewards, 38291 frames, score 0, max score 4
# Completed 128 games, 174 rewards, 38472 frames, score 0, max score 4
# Completed 129 games, 176 rewards, 38840 frames, score 1, max score 4
# Completed 130 games, 178 rewards, 39303 frames, score 1, max score 4
# Completed 131 games, 179 rewards, 39511 frames, score 0, max score 4
# Completed 132 games, 180 rewards, 39765 frames, score 0, max score 4
# Completed 133 games, 181 rewards, 40019 frames, score 0, max score 4
# Completed 134 games, 182 rewards, 40227 frames, score 0, max score 4
# Completed 135 games, 184 rewards, 40778 frames, score 1, max score 4
# Completed 136 games, 185 rewards, 41032 frames, score 0, max score 4
# Completed 137 games, 188 rewards, 41831 frames, score 2, max score 4
# Completed 138 games, 191 rewards, 42396 frames, score 2, max score 4
# Completed 139 games, 192 rewards, 42577 frames, score 0, max score 4
# Completed 140 games, 194 rewards, 42975 frames, score 1, max score 4
# Completed 141 games, 195 rewards, 43183 frames, score 0, max score 4
# Completed 142 games, 197 rewards, 44056 frames, score 1, max score 4
# Completed 143 games, 198 rewards, 44237 frames, score 0, max score 4
# Completed 144 games, 199 rewards, 44418 frames, score 0, max score 4
# Completed 145 games, 200 rewards, 44599 frames, score 0, max score 4
# Completed 146 games, 202 rewards, 45013 frames, score 1, max score 4
# Completed 147 games, 204 rewards, 45510 frames, score 1, max score 4
# Completed 148 games, 206 rewards, 45886 frames, score 1, max score 4
# Completed 149 games, 208 rewards, 46374 frames, score 1, max score 4
# Completed 150 games, 210 rewards, 46780 frames, score 1, max score 4
# Completed 151 games, 211 rewards, 46988 frames, score 0, max score 4
# Completed 152 games, 212 rewards, 47242 frames, score 0, max score 4
# Completed 153 games, 213 rewards, 47423 frames, score 0, max score 4
# Completed 154 games, 214 rewards, 47604 frames, score 0, max score 4
# Completed 155 games, 216 rewards, 48138 frames, score 1, max score 4
# Completed 156 games, 217 rewards, 48392 frames, score 0, max score 4
# Completed 157 games, 218 rewards, 48646 frames, score 0, max score 4
# Completed 158 games, 219 rewards, 48854 frames, score 0, max score 4
# Completed 159 games, 222 rewards, 49581 frames, score 2, max score 4
# Completed 160 games, 223 rewards, 49835 frames, score 0, max score 4
# Completed 161 games, 225 rewards, 50218 frames, score 1, max score 4
# Completed 162 games, 226 rewards, 50399 frames, score 0, max score 4
# Completed 163 games, 228 rewards, 50782 frames, score 1, max score 4
# Completed 164 games, 232 rewards, 51431 frames, score 3, max score 4
# Completed 165 games, 233 rewards, 51639 frames, score 0, max score 4
# Completed 166 games, 235 rewards, 52558 frames, score 1, max score 4
# Completed 167 games, 237 rewards, 52910 frames, score 1, max score 4
# Completed 168 games, 239 rewards, 53277 frames, score 1, max score 4
# Completed 169 games, 240 rewards, 53458 frames, score 0, max score 4
# Completed 170 games, 241 rewards, 53712 frames, score 0, max score 4
# Completed 171 games, 243 rewards, 54263 frames, score 1, max score 4
# Completed 172 games, 244 rewards, 54517 frames, score 0, max score 4
# Completed 173 games, 245 rewards, 54698 frames, score 0, max score 4
# Completed 174 games, 246 rewards, 54879 frames, score 0, max score 4
# Completed 175 games, 248 rewards, 55220 frames, score 1, max score 4
# Completed 176 games, 249 rewards, 55401 frames, score 0, max score 4
# Completed 177 games, 251 rewards, 55991 frames, score 1, max score 4
# Completed 178 games, 255 rewards, 57117 frames, score 3, max score 4
# Completed 179 games, 262 rewards, 59250 frames, score 6, max score 6
# Completed 180 games, 263 rewards, 59458 frames, score 0, max score 6
# Completed 181 games, 264 rewards, 59712 frames, score 0, max score 6
# Completed 182 games, 265 rewards, 59966 frames, score 0, max score 6
# Completed 183 games, 269 rewards, 60669 frames, score 3, max score 6
# Completed 184 games, 270 rewards, 60850 frames, score 0, max score 6
# Completed 185 games, 271 rewards, 61104 frames, score 0, max score 6
# Completed 186 games, 273 rewards, 61648 frames, score 1, max score 6
# Completed 187 games, 274 rewards, 61902 frames, score 0, max score 6
# Completed 188 games, 278 rewards, 62745 frames, score 3, max score 6
# Completed 189 games, 284 rewards, 63739 frames, score 5, max score 6
# Completed 190 games, 286 rewards, 64144 frames, score 1, max score 6
# Completed 191 games, 287 rewards, 64352 frames, score 0, max score 6
# Completed 192 games, 293 rewards, 66115 frames, score 5, max score 6
# Completed 193 games, 298 rewards, 67239 frames, score 4, max score 6
# Completed 194 games, 299 rewards, 67420 frames, score 0, max score 6
# Completed 195 games, 302 rewards, 68112 frames, score 2, max score 6
# Completed 196 games, 307 rewards, 69697 frames, score 4, max score 6
# Completed 197 games, 308 rewards, 69878 frames, score 0, max score 6
# Completed 198 games, 309 rewards, 70059 frames, score 0, max score 6
# Completed 199 games, 311 rewards, 70610 frames, score 1, max score 6
# Completed 200 games, 313 rewards, 71047 frames, score 1, max score 6
# Completed 201 games, 314 rewards, 71228 frames, score 0, max score 6
# Completed 202 games, 316 rewards, 71890 frames, score 1, max score 6
# Completed 203 games, 317 rewards, 72098 frames, score 0, max score 6
# Completed 204 games, 318 rewards, 72306 frames, score 0, max score 6
# Completed 205 games, 320 rewards, 72840 frames, score 1, max score 6
# Completed 206 games, 321 rewards, 73048 frames, score 0, max score 6
# Completed 207 games, 324 rewards, 73695 frames, score 2, max score 6
# Completed 208 games, 325 rewards, 73876 frames, score 0, max score 6
# Completed 209 games, 326 rewards, 74084 frames, score 0, max score 6
# Completed 210 games, 327 rewards, 74292 frames, score 0, max score 6
# Completed 211 games, 328 rewards, 74500 frames, score 0, max score 6
# Completed 212 games, 329 rewards, 74681 frames, score 0, max score 6
# Completed 213 games, 331 rewards, 75048 frames, score 1, max score 6
# Completed 214 games, 332 rewards, 75302 frames, score 0, max score 6
# Completed 215 games, 334 rewards, 75845 frames, score 1, max score 6
# Completed 216 games, 336 rewards, 76199 frames, score 1, max score 6
# Completed 217 games, 340 rewards, 77430 frames, score 3, max score 6
# Completed 218 games, 347 rewards, 78493 frames, score 6, max score 6
# Completed 219 games, 352 rewards, 79881 frames, score 4, max score 6
# Completed 220 games, 354 rewards, 80259 frames, score 1, max score 6
# Completed 221 games, 355 rewards, 80440 frames, score 0, max score 6
# Completed 222 games, 356 rewards, 80621 frames, score 0, max score 6
# Completed 223 games, 357 rewards, 80829 frames, score 0, max score 6
# Completed 224 games, 362 rewards, 81613 frames, score 4, max score 6
# Completed 225 games, 363 rewards, 81794 frames, score 0, max score 6
# Completed 226 games, 368 rewards, 82833 frames, score 4, max score 6
# Completed 227 games, 370 rewards, 83239 frames, score 1, max score 6
# Completed 228 games, 372 rewards, 83710 frames, score 1, max score 6
# Completed 229 games, 373 rewards, 83964 frames, score 0, max score 6
# Completed 230 games, 375 rewards, 84566 frames, score 1, max score 6
# Completed 231 games, 376 rewards, 84774 frames, score 0, max score 6
# Completed 232 games, 377 rewards, 85028 frames, score 0, max score 6
# Completed 233 games, 379 rewards, 85494 frames, score 1, max score 6
# Completed 234 games, 380 rewards, 85702 frames, score 0, max score 6
# Completed 235 games, 381 rewards, 85910 frames, score 0, max score 6
# Completed 236 games, 383 rewards, 86572 frames, score 1, max score 6
# Completed 237 games, 386 rewards, 88156 frames, score 2, max score 6
# Completed 238 games, 387 rewards, 88337 frames, score 0, max score 6
# Completed 239 games, 388 rewards, 88591 frames, score 0, max score 6
# Completed 240 games, 389 rewards, 88799 frames, score 0, max score 6
# Completed 241 games, 390 rewards, 89007 frames, score 0, max score 6
# Completed 242 games, 393 rewards, 89376 frames, score 2, max score 6
# Completed 243 games, 394 rewards, 89630 frames, score 0, max score 6
# Completed 244 games, 396 rewards, 90220 frames, score 1, max score 6
# Completed 245 games, 399 rewards, 90880 frames, score 2, max score 6
# Completed 246 games, 400 rewards, 91088 frames, score 0, max score 6
# Completed 247 games, 401 rewards, 91269 frames, score 0, max score 6
# Completed 248 games, 405 rewards, 92361 frames, score 3, max score 6
# Completed 249 games, 406 rewards, 92615 frames, score 0, max score 6
# Completed 250 games, 407 rewards, 92796 frames, score 0, max score 6
# Completed 251 games, 411 rewards, 93568 frames, score 3, max score 6
# Completed 252 games, 415 rewards, 94466 frames, score 3, max score 6
# Completed 253 games, 416 rewards, 94647 frames, score 0, max score 6
# Completed 254 games, 418 rewards, 95084 frames, score 1, max score 6
# Completed 255 games, 420 rewards, 95451 frames, score 1, max score 6
# Completed 256 games, 423 rewards, 96464 frames, score 2, max score 6
# Completed 257 games, 425 rewards, 97066 frames, score 1, max score 6
# Completed 258 games, 427 rewards, 97985 frames, score 1, max score 6
# Completed 259 games, 431 rewards, 98847 frames, score 3, max score 6
# Completed 260 games, 432 rewards, 99101 frames, score 0, max score 6
# Completed 261 games, 433 rewards, 99282 frames, score 0, max score 6
# Completed 262 games, 435 rewards, 99696 frames, score 1, max score 6
# Completed 263 games, 438 rewards, 100377 frames, score 2, max score 6
# Completed 264 games, 439 rewards, 100558 frames, score 0, max score 6
# Completed 265 games, 440 rewards, 100812 frames, score 0, max score 6
# Completed 266 games, 443 rewards, 101344 frames, score 2, max score 6
# Completed 267 games, 444 rewards, 101552 frames, score 0, max score 6
# Completed 268 games, 445 rewards, 101733 frames, score 0, max score 6
# Completed 269 games, 449 rewards, 102601 frames, score 3, max score 6
# Completed 270 games, 451 rewards, 103177 frames, score 1, max score 6
# Completed 271 games, 456 rewards, 103971 frames, score 4, max score 6
# Completed 272 games, 458 rewards, 104522 frames, score 1, max score 6
# Completed 273 games, 459 rewards, 104703 frames, score 0, max score 6
# Completed 274 games, 460 rewards, 104884 frames, score 0, max score 6
# Completed 275 games, 464 rewards, 105737 frames, score 3, max score 6
# Completed 276 games, 467 rewards, 106288 frames, score 2, max score 6
# Completed 277 games, 468 rewards, 106469 frames, score 0, max score 6
# Completed 278 games, 469 rewards, 106677 frames, score 0, max score 6
# Completed 279 games, 471 rewards, 107211 frames, score 1, max score 6
# Completed 280 games, 472 rewards, 107465 frames, score 0, max score 6
# Completed 281 games, 474 rewards, 108016 frames, score 1, max score 6
# Completed 282 games, 477 rewards, 108626 frames, score 2, max score 6
# Completed 283 games, 480 rewards, 109106 frames, score 2, max score 6
# Completed 284 games, 482 rewards, 109840 frames, score 1, max score 6
# Completed 285 games, 485 rewards, 110392 frames, score 2, max score 6
# Completed 286 games, 487 rewards, 110904 frames, score 1, max score 6
# Completed 287 games, 489 rewards, 111455 frames, score 1, max score 6
# Completed 288 games, 490 rewards, 111663 frames, score 0, max score 6
# Completed 289 games, 491 rewards, 111917 frames, score 0, max score 6
# Completed 290 games, 492 rewards, 112125 frames, score 0, max score 6
# Completed 291 games, 494 rewards, 112588 frames, score 1, max score 6
# Completed 292 games, 495 rewards, 112842 frames, score 0, max score 6
# Completed 293 games, 497 rewards, 113248 frames, score 1, max score 6
# Completed 294 games, 498 rewards, 113502 frames, score 0, max score 6
# Completed 295 games, 499 rewards, 113756 frames, score 0, max score 6
# The number of games played was 297
# The number of rewards was 500
# The size of each returned Q-matrix was (4000, 3)

# %% [markdown]
# The returned value of `q_states` is a list of 4000x3 numpy arrays (20 states, 3 actions).  The list contains `m_rewards` of these. We want to convert it into something that matplotlib can plot.

# %%
import numpy as np

Q = np.array([np.reshape(q,-1) for q in q_states])
print('Q is now of shape',Q.shape)
print('the max absolute value of Q is ',np.amax(abs(Q)))
# Out:
# Q is now of shape (500, 12000)
# the max absolute value of Q is  2.2573885172083834

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,6),layout='tight')
ax = [ fig.add_subplot(2,1,x) for x in range(1,3) ]
ax[0].plot(np.arange(0,len(q_states)),Q)
ax[0].set_title('Q values of all states')
ax[1].plot(np.arange(0,len(q_states)),q_achieved)
ax[1].set_title('Q values of state achieved at each time')
ax[1].set_ylabel('Reward number')
# Out:
# Text(0, 0.5, 'Reward number')

# %% [markdown]
# OK, now let's try running it for a much longer period -- say, 5000 complete games.  We won't ask it to print out any states this time.

# %%
scores, q_achieved, q_states = pong_game.run(m_games=5000, states=[])
# scores, q_achieved, q_states = pong_game.run(m_games=10000, states=[])

print('The number of games played was',len(scores))
print('The number of video frames was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 1 rewards, 255 frames, score 1, max score 6
# Completed 1 games, 3 rewards, 917 frames, score 1, max score 6
# Completed 2 games, 4 rewards, 1171 frames, score 0, max score 6
# Completed 3 games, 6 rewards, 1668 frames, score 1, max score 6
# Completed 4 games, 7 rewards, 1876 frames, score 0, max score 6
# Completed 5 games, 8 rewards, 2130 frames, score 0, max score 6
# Completed 6 games, 11 rewards, 2631 frames, score 2, max score 6
# Completed 7 games, 12 rewards, 2812 frames, score 0, max score 6
# Completed 8 games, 18 rewards, 3733 frames, score 5, max score 6
# Completed 9 games, 20 rewards, 4170 frames, score 1, max score 6
# Completed 10 games, 21 rewards, 4351 frames, score 0, max score 6
# Completed 11 games, 22 rewards, 4532 frames, score 0, max score 6
# Completed 12 games, 23 rewards, 4713 frames, score 0, max score 6
# Completed 13 games, 25 rewards, 5447 frames, score 1, max score 6
# Completed 14 games, 37 rewards, 10569 frames, score 11, max score 11
# Completed 15 games, 38 rewards, 10750 frames, score 0, max score 11
# Completed 16 games, 41 rewards, 11391 frames, score 2, max score 11
# Completed 17 games, 43 rewards, 12053 frames, score 1, max score 11
# Completed 18 games, 49 rewards, 13002 frames, score 5, max score 11
# Completed 19 games, 52 rewards, 14174 frames, score 2, max score 11
# Completed 20 games, 53 rewards, 14382 frames, score 0, max score 11
# Completed 21 games, 54 rewards, 14563 frames, score 0, max score 11
# Completed 22 games, 58 rewards, 15393 frames, score 3, max score 11
# Completed 23 games, 60 rewards, 15830 frames, score 1, max score 11
# Completed 24 games, 63 rewards, 16460 frames, score 2, max score 11
# Completed 25 games, 64 rewards, 16641 frames, score 0, max score 11
# Completed 26 games, 67 rewards, 17441 frames, score 2, max score 11
# Completed 27 games, 68 rewards, 17649 frames, score 0, max score 11
# Completed 28 games, 69 rewards, 17830 frames, score 0, max score 11
# Completed 29 games, 74 rewards, 18710 frames, score 4, max score 11
# Completed 30 games, 77 rewards, 19472 frames, score 2, max score 11
# Completed 31 games, 80 rewards, 21181 frames, score 2, max score 11
# Completed 32 games, 82 rewards, 21535 frames, score 1, max score 11
# Completed 33 games, 83 rewards, 21716 frames, score 0, max score 11
# Completed 34 games, 88 rewards, 22978 frames, score 4, max score 11
# Completed 35 games, 92 rewards, 24200 frames, score 3, max score 11
# Completed 36 games, 96 rewards, 25345 frames, score 3, max score 11
# Completed 37 games, 97 rewards, 25526 frames, score 0, max score 11
# Completed 38 games, 99 rewards, 26260 frames, score 1, max score 11
# Completed 39 games, 103 rewards, 26750 frames, score 3, max score 11
# Completed 40 games, 104 rewards, 27004 frames, score 0, max score 11
# Completed 41 games, 106 rewards, 27441 frames, score 1, max score 11
# Completed 42 games, 110 rewards, 28096 frames, score 3, max score 11
# Completed 43 games, 111 rewards, 28277 frames, score 0, max score 11
# Completed 44 games, 113 rewards, 28651 frames, score 1, max score 11
# Completed 45 games, 115 rewards, 29313 frames, score 1, max score 11
# Completed 46 games, 119 rewards, 30631 frames, score 3, max score 11
# Completed 47 games, 120 rewards, 30812 frames, score 0, max score 11
# Completed 48 games, 121 rewards, 31066 frames, score 0, max score 11
# Completed 49 games, 122 rewards, 31320 frames, score 0, max score 11
# Completed 50 games, 123 rewards, 31528 frames, score 0, max score 11
# Completed 51 games, 125 rewards, 31919 frames, score 1, max score 11
# Completed 52 games, 126 rewards, 32173 frames, score 0, max score 11
# Completed 53 games, 129 rewards, 33181 frames, score 2, max score 11
# Completed 54 games, 135 rewards, 34362 frames, score 5, max score 11
# Completed 55 games, 138 rewards, 34857 frames, score 2, max score 11
# Completed 56 games, 140 rewards, 35408 frames, score 1, max score 11
# Completed 57 games, 144 rewards, 36488 frames, score 3, max score 11
# Completed 58 games, 147 rewards, 37244 frames, score 2, max score 11
# Completed 59 games, 148 rewards, 37498 frames, score 0, max score 11
# Completed 60 games, 149 rewards, 37706 frames, score 0, max score 11
# Completed 61 games, 151 rewards, 38143 frames, score 1, max score 11
# Completed 62 games, 156 rewards, 39105 frames, score 4, max score 11
# Completed 63 games, 157 rewards, 39313 frames, score 0, max score 11
# Completed 64 games, 161 rewards, 40026 frames, score 3, max score 11
# Completed 65 games, 163 rewards, 40489 frames, score 1, max score 11
# Completed 66 games, 166 rewards, 42513 frames, score 2, max score 11
# Completed 67 games, 167 rewards, 42721 frames, score 0, max score 11
# Completed 68 games, 169 rewards, 43383 frames, score 1, max score 11
# Completed 69 games, 174 rewards, 44413 frames, score 4, max score 11
# Completed 70 games, 176 rewards, 44805 frames, score 1, max score 11
# Completed 71 games, 182 rewards, 47589 frames, score 5, max score 11
# Completed 72 games, 184 rewards, 48237 frames, score 1, max score 11
# Completed 73 games, 186 rewards, 48635 frames, score 1, max score 11
# Completed 74 games, 187 rewards, 48816 frames, score 0, max score 11
# Completed 75 games, 190 rewards, 49416 frames, score 2, max score 11
# Completed 76 games, 191 rewards, 49670 frames, score 0, max score 11
# Completed 77 games, 192 rewards, 49851 frames, score 0, max score 11
# Completed 78 games, 195 rewards, 50383 frames, score 2, max score 11
# Completed 79 games, 200 rewards, 52590 frames, score 4, max score 11
# Completed 80 games, 201 rewards, 52771 frames, score 0, max score 11
# Completed 81 games, 203 rewards, 53505 frames, score 1, max score 11
# Completed 82 games, 204 rewards, 53759 frames, score 0, max score 11
# Completed 83 games, 207 rewards, 54562 frames, score 2, max score 11
# Completed 84 games, 208 rewards, 54816 frames, score 0, max score 11
# Completed 85 games, 210 rewards, 55230 frames, score 1, max score 11
# Completed 86 games, 211 rewards, 55411 frames, score 0, max score 11
# Completed 87 games, 212 rewards, 55592 frames, score 0, max score 11
# Completed 88 games, 213 rewards, 55773 frames, score 0, max score 11
# Completed 89 games, 215 rewards, 56435 frames, score 1, max score 11
# Completed 90 games, 217 rewards, 56986 frames, score 1, max score 11
# Completed 91 games, 223 rewards, 58473 frames, score 5, max score 11
# Completed 92 games, 226 rewards, 59195 frames, score 2, max score 11
# Completed 93 games, 228 rewards, 59857 frames, score 1, max score 11
# Completed 94 games, 229 rewards, 60111 frames, score 0, max score 11
# Completed 95 games, 230 rewards, 60292 frames, score 0, max score 11
# Completed 96 games, 231 rewards, 60473 frames, score 0, max score 11
# Completed 97 games, 234 rewards, 61061 frames, score 2, max score 11
# Completed 98 games, 239 rewards, 62619 frames, score 4, max score 11
# Completed 99 games, 241 rewards, 63281 frames, score 1, max score 11
# Completed 100 games, 242 rewards, 63535 frames, score 0, max score 11
# Completed 101 games, 245 rewards, 64123 frames, score 2, max score 11
# Completed 102 games, 246 rewards, 64304 frames, score 0, max score 11
# Completed 103 games, 247 rewards, 64512 frames, score 0, max score 11
# Completed 104 games, 248 rewards, 64693 frames, score 0, max score 11
# Completed 105 games, 251 rewards, 65578 frames, score 2, max score 11
# Completed 106 games, 253 rewards, 65946 frames, score 1, max score 11
# Completed 107 games, 255 rewards, 66287 frames, score 1, max score 11
# Completed 108 games, 257 rewards, 66830 frames, score 1, max score 11
# Completed 109 games, 260 rewards, 67318 frames, score 2, max score 11
# Completed 110 games, 261 rewards, 67526 frames, score 0, max score 11
# Completed 111 games, 263 rewards, 67924 frames, score 1, max score 11
# Completed 112 games, 264 rewards, 68105 frames, score 0, max score 11
# Completed 113 games, 265 rewards, 68313 frames, score 0, max score 11
# Completed 114 games, 266 rewards, 68494 frames, score 0, max score 11
# Completed 115 games, 267 rewards, 68702 frames, score 0, max score 11
# Completed 116 games, 272 rewards, 70030 frames, score 4, max score 11
# Completed 117 games, 273 rewards, 70211 frames, score 0, max score 11
# Completed 118 games, 275 rewards, 70801 frames, score 1, max score 11
# Completed 119 games, 279 rewards, 71635 frames, score 3, max score 11
# Completed 120 games, 281 rewards, 72063 frames, score 1, max score 11
# Completed 121 games, 286 rewards, 73660 frames, score 4, max score 11
# Completed 122 games, 290 rewards, 74412 frames, score 3, max score 11
# Completed 123 games, 293 rewards, 75051 frames, score 2, max score 11
# Completed 124 games, 294 rewards, 75305 frames, score 0, max score 11
# Completed 125 games, 298 rewards, 76922 frames, score 3, max score 11
# Completed 126 games, 299 rewards, 77103 frames, score 0, max score 11
# Completed 127 games, 300 rewards, 77311 frames, score 0, max score 11
# Completed 128 games, 303 rewards, 78192 frames, score 2, max score 11
# Completed 129 games, 304 rewards, 78373 frames, score 0, max score 11
# Completed 130 games, 307 rewards, 79059 frames, score 2, max score 11
# Completed 131 games, 308 rewards, 79240 frames, score 0, max score 11
# Completed 132 games, 309 rewards, 79421 frames, score 0, max score 11
# Completed 133 games, 313 rewards, 80668 frames, score 3, max score 11
# Completed 134 games, 314 rewards, 80922 frames, score 0, max score 11
# Completed 135 games, 315 rewards, 81103 frames, score 0, max score 11
# Completed 136 games, 317 rewards, 81765 frames, score 1, max score 11
# Completed 137 games, 320 rewards, 82172 frames, score 2, max score 11
# Completed 138 games, 322 rewards, 82723 frames, score 1, max score 11
# Completed 139 games, 323 rewards, 82904 frames, score 0, max score 11
# Completed 140 games, 324 rewards, 83085 frames, score 0, max score 11
# Completed 141 games, 327 rewards, 83685 frames, score 2, max score 11
# Completed 142 games, 333 rewards, 85913 frames, score 5, max score 11
# Completed 143 games, 336 rewards, 86761 frames, score 2, max score 11
# Completed 144 games, 338 rewards, 87363 frames, score 1, max score 11
# Completed 145 games, 339 rewards, 87617 frames, score 0, max score 11
# Completed 146 games, 341 rewards, 88105 frames, score 1, max score 11
# Completed 147 games, 342 rewards, 88313 frames, score 0, max score 11
# Completed 148 games, 344 rewards, 88741 frames, score 1, max score 11
# Completed 149 games, 350 rewards, 89971 frames, score 5, max score 11
# Completed 150 games, 351 rewards, 90179 frames, score 0, max score 11
# Completed 151 games, 352 rewards, 90387 frames, score 0, max score 11
# Completed 152 games, 354 rewards, 90938 frames, score 1, max score 11
# Completed 153 games, 356 rewards, 91600 frames, score 1, max score 11
# Completed 154 games, 357 rewards, 91854 frames, score 0, max score 11
# Completed 155 games, 358 rewards, 92108 frames, score 0, max score 11
# Completed 156 games, 363 rewards, 92960 frames, score 4, max score 11
# Completed 157 games, 365 rewards, 93472 frames, score 1, max score 11
# Completed 158 games, 366 rewards, 93680 frames, score 0, max score 11
# Completed 159 games, 367 rewards, 93934 frames, score 0, max score 11
# Completed 160 games, 371 rewards, 94634 frames, score 3, max score 11
# Completed 161 games, 372 rewards, 94842 frames, score 0, max score 11
# Completed 162 games, 374 rewards, 95256 frames, score 1, max score 11
# Completed 163 games, 376 rewards, 95716 frames, score 1, max score 11
# Completed 164 games, 377 rewards, 95897 frames, score 0, max score 11
# Completed 165 games, 379 rewards, 96360 frames, score 1, max score 11
# Completed 166 games, 380 rewards, 96614 frames, score 0, max score 11
# Completed 167 games, 387 rewards, 98128 frames, score 6, max score 11
# Completed 168 games, 392 rewards, 99440 frames, score 4, max score 11
# Completed 169 games, 403 rewards, 101403 frames, score 10, max score 11
# Completed 170 games, 410 rewards, 103057 frames, score 6, max score 11
# Completed 171 games, 415 rewards, 104281 frames, score 4, max score 11
# Completed 172 games, 419 rewards, 104976 frames, score 3, max score 11
# Completed 173 games, 420 rewards, 105230 frames, score 0, max score 11
# Completed 174 games, 421 rewards, 105438 frames, score 0, max score 11
# Completed 175 games, 426 rewards, 106525 frames, score 4, max score 11
# Completed 176 games, 427 rewards, 106733 frames, score 0, max score 11
# Completed 177 games, 428 rewards, 106941 frames, score 0, max score 11
# Completed 178 games, 430 rewards, 107603 frames, score 1, max score 11
# Completed 179 games, 431 rewards, 107811 frames, score 0, max score 11
# Completed 180 games, 432 rewards, 107992 frames, score 0, max score 11
# Completed 181 games, 436 rewards, 108904 frames, score 3, max score 11
# Completed 182 games, 437 rewards, 109112 frames, score 0, max score 11
# Completed 183 games, 443 rewards, 110288 frames, score 5, max score 11
# Completed 184 games, 444 rewards, 110469 frames, score 0, max score 11
# Completed 185 games, 445 rewards, 110723 frames, score 0, max score 11
# Completed 186 games, 446 rewards, 110977 frames, score 0, max score 11
# Completed 187 games, 447 rewards, 111158 frames, score 0, max score 11
# Completed 188 games, 457 rewards, 115096 frames, score 9, max score 11
# Completed 189 games, 462 rewards, 116304 frames, score 4, max score 11
# Completed 190 games, 467 rewards, 118499 frames, score 4, max score 11
# Completed 191 games, 468 rewards, 118680 frames, score 0, max score 11
# Completed 192 games, 469 rewards, 118888 frames, score 0, max score 11
# Completed 193 games, 470 rewards, 119069 frames, score 0, max score 11
# Completed 194 games, 471 rewards, 119323 frames, score 0, max score 11
# Completed 195 games, 472 rewards, 119531 frames, score 0, max score 11
# Completed 196 games, 473 rewards, 119712 frames, score 0, max score 11
# Completed 197 games, 475 rewards, 120080 frames, score 1, max score 11
# Completed 198 games, 478 rewards, 120636 frames, score 2, max score 11
# Completed 199 games, 479 rewards, 120890 frames, score 0, max score 11
# Completed 200 games, 484 rewards, 122644 frames, score 4, max score 11
# Completed 201 games, 486 rewards, 123195 frames, score 1, max score 11
# Completed 202 games, 487 rewards, 123449 frames, score 0, max score 11
# Completed 203 games, 490 rewards, 124297 frames, score 2, max score 11
# Completed 204 games, 495 rewards, 125282 frames, score 4, max score 11
# Completed 205 games, 499 rewards, 127527 frames, score 3, max score 11
# Completed 206 games, 504 rewards, 128820 frames, score 4, max score 11
# Completed 207 games, 506 rewards, 129308 frames, score 1, max score 11
# Completed 208 games, 507 rewards, 129489 frames, score 0, max score 11
# Completed 209 games, 508 rewards, 129697 frames, score 0, max score 11
# Completed 210 games, 517 rewards, 133631 frames, score 8, max score 11
# Completed 211 games, 520 rewards, 134282 frames, score 2, max score 11
# Completed 212 games, 527 rewards, 136160 frames, score 6, max score 11
# Completed 213 games, 528 rewards, 136341 frames, score 0, max score 11
# Completed 214 games, 532 rewards, 137057 frames, score 3, max score 11
# Completed 215 games, 535 rewards, 137960 frames, score 2, max score 11
# Completed 216 games, 537 rewards, 138328 frames, score 1, max score 11
# Completed 217 games, 541 rewards, 138982 frames, score 3, max score 11
# Completed 218 games, 547 rewards, 140076 frames, score 5, max score 11
# Completed 219 games, 555 rewards, 141571 frames, score 7, max score 11
# Completed 220 games, 561 rewards, 142941 frames, score 5, max score 11
# Completed 221 games, 563 rewards, 143531 frames, score 1, max score 11
# Completed 222 games, 565 rewards, 144028 frames, score 1, max score 11
# Completed 223 games, 567 rewards, 144517 frames, score 1, max score 11
# Completed 224 games, 571 rewards, 145330 frames, score 3, max score 11
# Completed 225 games, 575 rewards, 147052 frames, score 3, max score 11
# Completed 226 games, 578 rewards, 147642 frames, score 2, max score 11
# Completed 227 games, 580 rewards, 148154 frames, score 1, max score 11
# Completed 228 games, 582 rewards, 148522 frames, score 1, max score 11
# Completed 229 games, 583 rewards, 148730 frames, score 0, max score 11
# Completed 230 games, 586 rewards, 149500 frames, score 2, max score 11
# Completed 231 games, 588 rewards, 149960 frames, score 1, max score 11
# Completed 232 games, 592 rewards, 150803 frames, score 3, max score 11
# Completed 233 games, 597 rewards, 152280 frames, score 4, max score 11
# Completed 234 games, 599 rewards, 153014 frames, score 1, max score 11
# Completed 235 games, 601 rewards, 153397 frames, score 1, max score 11
# Completed 236 games, 603 rewards, 153940 frames, score 1, max score 11
# Completed 237 games, 604 rewards, 154148 frames, score 0, max score 11
# Completed 238 games, 613 rewards, 155806 frames, score 8, max score 11
# Completed 239 games, 617 rewards, 156697 frames, score 3, max score 11
# Completed 240 games, 619 rewards, 157049 frames, score 1, max score 11
# Completed 241 games, 622 rewards, 157626 frames, score 2, max score 11
# Completed 242 games, 623 rewards, 157880 frames, score 0, max score 11
# Completed 243 games, 626 rewards, 158892 frames, score 2, max score 11
# Completed 244 games, 627 rewards, 159100 frames, score 0, max score 11
# Completed 245 games, 628 rewards, 159308 frames, score 0, max score 11
# Completed 246 games, 631 rewards, 159990 frames, score 2, max score 11
# Completed 247 games, 632 rewards, 160198 frames, score 0, max score 11
# Completed 248 games, 634 rewards, 160592 frames, score 1, max score 11
# Completed 249 games, 636 rewards, 161511 frames, score 1, max score 11
# Completed 250 games, 639 rewards, 162161 frames, score 2, max score 11
# Completed 251 games, 643 rewards, 163069 frames, score 3, max score 11
# Completed 252 games, 644 rewards, 163250 frames, score 0, max score 11
# Completed 253 games, 652 rewards, 164581 frames, score 7, max score 11
# Completed 254 games, 655 rewards, 165072 frames, score 2, max score 11
# Completed 255 games, 657 rewards, 165466 frames, score 1, max score 11
# Completed 256 games, 661 rewards, 166236 frames, score 3, max score 11
# Completed 257 games, 669 rewards, 169513 frames, score 7, max score 11
# Completed 258 games, 670 rewards, 169767 frames, score 0, max score 11
# Completed 259 games, 672 rewards, 170161 frames, score 1, max score 11
# Completed 260 games, 674 rewards, 170598 frames, score 1, max score 11
# Completed 261 games, 678 rewards, 171489 frames, score 3, max score 11
# Completed 262 games, 679 rewards, 171697 frames, score 0, max score 11
# Completed 263 games, 682 rewards, 172543 frames, score 2, max score 11
# Completed 264 games, 683 rewards, 172751 frames, score 0, max score 11
# Completed 265 games, 684 rewards, 172959 frames, score 0, max score 11
# Completed 266 games, 686 rewards, 173561 frames, score 1, max score 11
# Completed 267 games, 687 rewards, 173769 frames, score 0, max score 11
# Completed 268 games, 689 rewards, 174175 frames, score 1, max score 11
# Completed 269 games, 693 rewards, 175883 frames, score 3, max score 11
# Completed 270 games, 695 rewards, 176288 frames, score 1, max score 11
# Completed 271 games, 696 rewards, 176496 frames, score 0, max score 11
# Completed 272 games, 698 rewards, 176924 frames, score 1, max score 11
# Completed 273 games, 699 rewards, 177132 frames, score 0, max score 11
# Completed 274 games, 701 rewards, 177499 frames, score 1, max score 11
# Completed 275 games, 702 rewards, 177680 frames, score 0, max score 11
# Completed 276 games, 704 rewards, 178140 frames, score 1, max score 11
# Completed 277 games, 705 rewards, 178321 frames, score 0, max score 11
# Completed 278 games, 707 rewards, 178901 frames, score 1, max score 11
# Completed 279 games, 710 rewards, 179426 frames, score 2, max score 11
# Completed 280 games, 711 rewards, 179607 frames, score 0, max score 11
# Completed 281 games, 714 rewards, 180218 frames, score 2, max score 11
# Completed 282 games, 716 rewards, 180880 frames, score 1, max score 11
# Completed 283 games, 717 rewards, 181134 frames, score 0, max score 11
# Completed 284 games, 718 rewards, 181388 frames, score 0, max score 11
# Completed 285 games, 720 rewards, 181885 frames, score 1, max score 11
# Completed 286 games, 726 rewards, 182744 frames, score 5, max score 11
# Completed 287 games, 727 rewards, 182998 frames, score 0, max score 11
# Completed 288 games, 732 rewards, 183790 frames, score 4, max score 11
# Completed 289 games, 735 rewards, 184398 frames, score 2, max score 11
# Completed 290 games, 740 rewards, 185624 frames, score 4, max score 11
# Completed 291 games, 742 rewards, 186007 frames, score 1, max score 11
# Completed 292 games, 744 rewards, 186348 frames, score 1, max score 11
# Completed 293 games, 749 rewards, 187413 frames, score 4, max score 11
# Completed 294 games, 750 rewards, 187621 frames, score 0, max score 11
# Completed 295 games, 754 rewards, 188470 frames, score 3, max score 11
# Completed 296 games, 759 rewards, 189276 frames, score 4, max score 11
# Completed 297 games, 761 rewards, 189739 frames, score 1, max score 11
# Completed 298 games, 764 rewards, 190549 frames, score 2, max score 11
# Completed 299 games, 770 rewards, 191806 frames, score 5, max score 11
# Completed 300 games, 773 rewards, 192373 frames, score 2, max score 11
# Completed 301 games, 774 rewards, 192581 frames, score 0, max score 11
# Completed 302 games, 777 rewards, 193184 frames, score 2, max score 11
# Completed 303 games, 779 rewards, 193774 frames, score 1, max score 11
# Completed 304 games, 781 rewards, 194262 frames, score 1, max score 11
# Completed 305 games, 782 rewards, 194470 frames, score 0, max score 11
# Completed 306 games, 786 rewards, 195340 frames, score 3, max score 11
# Completed 307 games, 787 rewards, 195521 frames, score 0, max score 11
# Completed 308 games, 789 rewards, 196018 frames, score 1, max score 11
# Completed 309 games, 794 rewards, 198402 frames, score 4, max score 11
# Completed 310 games, 798 rewards, 199259 frames, score 3, max score 11
# Completed 311 games, 799 rewards, 199467 frames, score 0, max score 11
# Completed 312 games, 800 rewards, 199648 frames, score 0, max score 11
# Completed 313 games, 801 rewards, 199856 frames, score 0, max score 11
# Completed 314 games, 802 rewards, 200110 frames, score 0, max score 11
# Completed 315 games, 803 rewards, 200364 frames, score 0, max score 11
# Completed 316 games, 805 rewards, 200731 frames, score 1, max score 11
# Completed 317 games, 806 rewards, 200912 frames, score 0, max score 11
# Completed 318 games, 807 rewards, 201166 frames, score 0, max score 11
# Completed 319 games, 809 rewards, 201580 frames, score 1, max score 11
# Completed 320 games, 810 rewards, 201788 frames, score 0, max score 11
# Completed 321 games, 811 rewards, 201996 frames, score 0, max score 11
# Completed 322 games, 814 rewards, 202949 frames, score 2, max score 11
# Completed 323 games, 815 rewards, 203203 frames, score 0, max score 11
# Completed 324 games, 816 rewards, 203457 frames, score 0, max score 11
# Completed 325 games, 819 rewards, 204164 frames, score 2, max score 11
# Completed 326 games, 820 rewards, 204418 frames, score 0, max score 11
# Completed 327 games, 824 rewards, 205095 frames, score 3, max score 11
# Completed 328 games, 826 rewards, 205646 frames, score 1, max score 11
# Completed 329 games, 827 rewards, 205827 frames, score 0, max score 11
# Completed 330 games, 834 rewards, 208307 frames, score 6, max score 11
# Completed 331 games, 835 rewards, 208561 frames, score 0, max score 11
# Completed 332 games, 836 rewards, 208815 frames, score 0, max score 11
# Completed 333 games, 837 rewards, 209069 frames, score 0, max score 11
# Completed 334 games, 838 rewards, 209323 frames, score 0, max score 11
# Completed 335 games, 839 rewards, 209504 frames, score 0, max score 11
# Completed 336 games, 840 rewards, 209758 frames, score 0, max score 11
# Completed 337 games, 843 rewards, 210238 frames, score 2, max score 11
# Completed 338 games, 846 rewards, 211042 frames, score 2, max score 11
# Completed 339 games, 850 rewards, 211946 frames, score 3, max score 11
# Completed 340 games, 851 rewards, 212200 frames, score 0, max score 11
# Completed 341 games, 853 rewards, 212862 frames, score 1, max score 11
# Completed 342 games, 854 rewards, 213116 frames, score 0, max score 11
# Completed 343 games, 857 rewards, 213842 frames, score 2, max score 11
# Completed 344 games, 859 rewards, 214393 frames, score 1, max score 11
# Completed 345 games, 861 rewards, 214905 frames, score 1, max score 11
# Completed 346 games, 862 rewards, 215159 frames, score 0, max score 11
# Completed 347 games, 868 rewards, 216286 frames, score 5, max score 11
# Completed 348 games, 874 rewards, 217428 frames, score 5, max score 11
# Completed 349 games, 876 rewards, 217826 frames, score 1, max score 11
# Completed 350 games, 881 rewards, 220249 frames, score 4, max score 11
# Completed 351 games, 883 rewards, 220800 frames, score 1, max score 11
# Completed 352 games, 884 rewards, 220981 frames, score 0, max score 11
# Completed 353 games, 886 rewards, 221333 frames, score 1, max score 11
# Completed 354 games, 888 rewards, 221995 frames, score 1, max score 11
# Completed 355 games, 891 rewards, 222603 frames, score 2, max score 11
# Completed 356 games, 893 rewards, 222955 frames, score 1, max score 11
# Completed 357 games, 894 rewards, 223163 frames, score 0, max score 11
# Completed 358 games, 896 rewards, 223515 frames, score 1, max score 11
# Completed 359 games, 901 rewards, 224481 frames, score 4, max score 11
# Completed 360 games, 910 rewards, 226216 frames, score 8, max score 11
# Completed 361 games, 911 rewards, 226424 frames, score 0, max score 11
# Completed 362 games, 913 rewards, 226937 frames, score 1, max score 11
# Completed 363 games, 917 rewards, 227703 frames, score 3, max score 11
# Completed 364 games, 919 rewards, 228131 frames, score 1, max score 11
# Completed 365 games, 924 rewards, 229445 frames, score 4, max score 11
# Completed 366 games, 931 rewards, 231470 frames, score 6, max score 11
# Completed 367 games, 932 rewards, 231724 frames, score 0, max score 11
# Completed 368 games, 936 rewards, 233244 frames, score 3, max score 11
# Completed 369 games, 941 rewards, 234821 frames, score 4, max score 11
# Completed 370 games, 942 rewards, 235002 frames, score 0, max score 11
# Completed 371 games, 943 rewards, 235183 frames, score 0, max score 11
# Completed 372 games, 945 rewards, 235611 frames, score 1, max score 11
# Completed 373 games, 947 rewards, 236530 frames, score 1, max score 11
# Completed 374 games, 949 rewards, 236944 frames, score 1, max score 11
# Completed 375 games, 950 rewards, 237152 frames, score 0, max score 11
# Completed 376 games, 951 rewards, 237406 frames, score 0, max score 11
# Completed 377 games, 955 rewards, 238379 frames, score 3, max score 11
# Completed 378 games, 957 rewards, 239067 frames, score 1, max score 11
# Completed 379 games, 960 rewards, 239855 frames, score 2, max score 11
# Completed 380 games, 962 rewards, 240315 frames, score 1, max score 11
# Completed 381 games, 969 rewards, 244460 frames, score 6, max score 11
# Completed 382 games, 972 rewards, 245007 frames, score 2, max score 11
# Completed 383 games, 973 rewards, 245261 frames, score 0, max score 11
# Completed 384 games, 975 rewards, 245749 frames, score 1, max score 11
# Completed 385 games, 979 rewards, 247319 frames, score 3, max score 11
# Completed 386 games, 985 rewards, 248319 frames, score 5, max score 11
# Completed 387 games, 986 rewards, 248500 frames, score 0, max score 11
# Completed 388 games, 989 rewards, 249209 frames, score 2, max score 11
# Completed 389 games, 992 rewards, 249830 frames, score 2, max score 11
# Completed 390 games, 993 rewards, 250084 frames, score 0, max score 11
# Completed 391 games, 996 rewards, 250692 frames, score 2, max score 11
# Completed 392 games, 998 rewards, 251189 frames, score 1, max score 11
# Completed 393 games, 1001 rewards, 252128 frames, score 2, max score 11
# Completed 394 games, 1004 rewards, 252648 frames, score 2, max score 11
# Completed 395 games, 1005 rewards, 252829 frames, score 0, max score 11
# Completed 396 games, 1012 rewards, 254341 frames, score 6, max score 11
# Completed 397 games, 1018 rewards, 256730 frames, score 5, max score 11
# Completed 398 games, 1020 rewards, 257128 frames, score 1, max score 11
# Completed 399 games, 1023 rewards, 257665 frames, score 2, max score 11
# Completed 400 games, 1024 rewards, 257846 frames, score 0, max score 11
# Completed 401 games, 1025 rewards, 258100 frames, score 0, max score 11
# Completed 402 games, 1028 rewards, 258685 frames, score 2, max score 11
# Completed 403 games, 1031 rewards, 259392 frames, score 2, max score 11
# Completed 404 games, 1032 rewards, 259646 frames, score 0, max score 11
# Completed 405 games, 1038 rewards, 260661 frames, score 5, max score 11
# Completed 406 games, 1045 rewards, 263776 frames, score 6, max score 11
# Completed 407 games, 1050 rewards, 265490 frames, score 4, max score 11
# Completed 408 games, 1057 rewards, 266739 frames, score 6, max score 11
# Completed 409 games, 1059 rewards, 267091 frames, score 1, max score 11
# Completed 410 games, 1062 rewards, 267724 frames, score 2, max score 11
# Completed 411 games, 1066 rewards, 268384 frames, score 3, max score 11
# Completed 412 games, 1070 rewards, 269338 frames, score 3, max score 11
# Completed 413 games, 1075 rewards, 270569 frames, score 4, max score 11
# Completed 414 games, 1090 rewards, 272902 frames, score 14, max score 14
# Completed 415 games, 1092 rewards, 273254 frames, score 1, max score 14
# Completed 416 games, 1094 rewards, 273751 frames, score 1, max score 14
# Completed 417 games, 1098 rewards, 274433 frames, score 3, max score 14
# Completed 418 games, 1105 rewards, 275687 frames, score 6, max score 14
# Completed 419 games, 1107 rewards, 276150 frames, score 1, max score 14
# Completed 420 games, 1108 rewards, 276404 frames, score 0, max score 14
# Completed 421 games, 1113 rewards, 277363 frames, score 4, max score 14
# Completed 422 games, 1114 rewards, 277617 frames, score 0, max score 14
# Completed 423 games, 1117 rewards, 278178 frames, score 2, max score 14
# Completed 424 games, 1118 rewards, 278386 frames, score 0, max score 14
# Completed 425 games, 1122 rewards, 279742 frames, score 3, max score 14
# Completed 426 games, 1124 rewards, 280404 frames, score 1, max score 14
# Completed 427 games, 1126 rewards, 281066 frames, score 1, max score 14
# Completed 428 games, 1128 rewards, 281503 frames, score 1, max score 14
# Completed 429 games, 1129 rewards, 281684 frames, score 0, max score 14
# Completed 430 games, 1131 rewards, 282078 frames, score 1, max score 14
# Completed 431 games, 1133 rewards, 282997 frames, score 1, max score 14
# Completed 432 games, 1134 rewards, 283205 frames, score 0, max score 14
# Completed 433 games, 1137 rewards, 284144 frames, score 2, max score 14
# Completed 434 games, 1144 rewards, 285849 frames, score 6, max score 14
# Completed 435 games, 1150 rewards, 287500 frames, score 5, max score 14
# Completed 436 games, 1151 rewards, 287754 frames, score 0, max score 14
# Completed 437 games, 1156 rewards, 289282 frames, score 4, max score 14
# Completed 438 games, 1158 rewards, 289719 frames, score 1, max score 14
# Completed 439 games, 1165 rewards, 290809 frames, score 6, max score 14
# Completed 440 games, 1168 rewards, 291300 frames, score 2, max score 14
# Completed 441 games, 1173 rewards, 292163 frames, score 4, max score 14
# Completed 442 games, 1174 rewards, 292371 frames, score 0, max score 14
# Completed 443 games, 1175 rewards, 292552 frames, score 0, max score 14
# Completed 444 games, 1180 rewards, 293580 frames, score 4, max score 14
# Completed 445 games, 1182 rewards, 293986 frames, score 1, max score 14
# Completed 446 games, 1190 rewards, 296275 frames, score 7, max score 14
# Completed 447 games, 1195 rewards, 297607 frames, score 4, max score 14
# Completed 448 games, 1200 rewards, 298727 frames, score 4, max score 14
# Completed 449 games, 1203 rewards, 300261 frames, score 2, max score 14
# Completed 450 games, 1211 rewards, 301770 frames, score 7, max score 14
# Completed 451 games, 1215 rewards, 302615 frames, score 3, max score 14
# Completed 452 games, 1220 rewards, 303614 frames, score 4, max score 14
# Completed 453 games, 1225 rewards, 304465 frames, score 4, max score 14
# Completed 454 games, 1233 rewards, 305727 frames, score 7, max score 14
# Completed 455 games, 1234 rewards, 305935 frames, score 0, max score 14
# Completed 456 games, 1235 rewards, 306189 frames, score 0, max score 14
# Completed 457 games, 1236 rewards, 306370 frames, score 0, max score 14
# Completed 458 games, 1238 rewards, 306972 frames, score 1, max score 14
# Completed 459 games, 1240 rewards, 307414 frames, score 1, max score 14
# Completed 460 games, 1246 rewards, 308865 frames, score 5, max score 14
# Completed 461 games, 1252 rewards, 310051 frames, score 5, max score 14
# Completed 462 games, 1254 rewards, 310419 frames, score 1, max score 14
# Completed 463 games, 1261 rewards, 312029 frames, score 6, max score 14
# Completed 464 games, 1262 rewards, 312283 frames, score 0, max score 14
# Completed 465 games, 1264 rewards, 312817 frames, score 1, max score 14
# Completed 466 games, 1266 rewards, 313368 frames, score 1, max score 14
# Completed 467 games, 1267 rewards, 313622 frames, score 0, max score 14
# Completed 468 games, 1273 rewards, 314721 frames, score 5, max score 14
# Completed 469 games, 1275 rewards, 315149 frames, score 1, max score 14
# Completed 470 games, 1277 rewards, 315547 frames, score 1, max score 14
# Completed 471 games, 1278 rewards, 315801 frames, score 0, max score 14
# Completed 472 games, 1280 rewards, 316264 frames, score 1, max score 14
# Completed 473 games, 1281 rewards, 316518 frames, score 0, max score 14
# Completed 474 games, 1288 rewards, 317889 frames, score 6, max score 14
# Completed 475 games, 1289 rewards, 318097 frames, score 0, max score 14
# Completed 476 games, 1297 rewards, 322630 frames, score 7, max score 14
# Completed 477 games, 1298 rewards, 322838 frames, score 0, max score 14
# Completed 478 games, 1299 rewards, 323046 frames, score 0, max score 14
# Completed 479 games, 1302 rewards, 323526 frames, score 2, max score 14
# Completed 480 games, 1306 rewards, 324521 frames, score 3, max score 14
# Completed 481 games, 1308 rewards, 325072 frames, score 1, max score 14
# Completed 482 games, 1315 rewards, 326653 frames, score 6, max score 14
# Completed 483 games, 1316 rewards, 326834 frames, score 0, max score 14
# Completed 484 games, 1320 rewards, 327558 frames, score 3, max score 14
# Completed 485 games, 1321 rewards, 327766 frames, score 0, max score 14
# Completed 486 games, 1324 rewards, 328370 frames, score 2, max score 14
# Completed 487 games, 1335 rewards, 332672 frames, score 10, max score 14
# Completed 488 games, 1338 rewards, 333242 frames, score 2, max score 14
# Completed 489 games, 1339 rewards, 333423 frames, score 0, max score 14
# Completed 490 games, 1342 rewards, 334115 frames, score 2, max score 14
# Completed 491 games, 1348 rewards, 335912 frames, score 5, max score 14
# Completed 492 games, 1355 rewards, 337291 frames, score 6, max score 14
# Completed 493 games, 1356 rewards, 337472 frames, score 0, max score 14
# Completed 494 games, 1360 rewards, 338446 frames, score 3, max score 14
# Completed 495 games, 1363 rewards, 339556 frames, score 2, max score 14
# Completed 496 games, 1364 rewards, 339810 frames, score 0, max score 14
# Completed 497 games, 1365 rewards, 340064 frames, score 0, max score 14
# Completed 498 games, 1370 rewards, 341039 frames, score 4, max score 14
# Completed 499 games, 1371 rewards, 341293 frames, score 0, max score 14
# Completed 500 games, 1375 rewards, 342010 frames, score 3, max score 14
# Completed 501 games, 1376 rewards, 342191 frames, score 0, max score 14
# Completed 502 games, 1378 rewards, 342589 frames, score 1, max score 14
# Completed 503 games, 1383 rewards, 343487 frames, score 4, max score 14
# Completed 504 games, 1391 rewards, 347327 frames, score 7, max score 14
# Completed 505 games, 1397 rewards, 349057 frames, score 5, max score 14
# Completed 506 games, 1399 rewards, 349494 frames, score 1, max score 14
# Completed 507 games, 1408 rewards, 350896 frames, score 8, max score 14
# Completed 508 games, 1412 rewards, 351711 frames, score 3, max score 14
# Completed 509 games, 1413 rewards, 351892 frames, score 0, max score 14
# Completed 510 games, 1416 rewards, 352794 frames, score 2, max score 14
# Completed 511 games, 1418 rewards, 353208 frames, score 1, max score 14
# Completed 512 games, 1430 rewards, 355166 frames, score 11, max score 14
# Completed 513 games, 1431 rewards, 355420 frames, score 0, max score 14
# Completed 514 games, 1433 rewards, 355787 frames, score 1, max score 14
# Completed 515 games, 1438 rewards, 357186 frames, score 4, max score 14
# Completed 516 games, 1443 rewards, 358275 frames, score 4, max score 14
# Completed 517 games, 1448 rewards, 360147 frames, score 4, max score 14
# Completed 518 games, 1449 rewards, 360328 frames, score 0, max score 14
# Completed 519 games, 1454 rewards, 361913 frames, score 4, max score 14
# Completed 520 games, 1458 rewards, 362756 frames, score 3, max score 14
# Completed 521 games, 1459 rewards, 362964 frames, score 0, max score 14
# Completed 522 games, 1462 rewards, 363660 frames, score 2, max score 14
# Completed 523 games, 1467 rewards, 365687 frames, score 4, max score 14
# Completed 524 games, 1468 rewards, 365941 frames, score 0, max score 14
# Completed 525 games, 1470 rewards, 366492 frames, score 1, max score 14
# Completed 526 games, 1476 rewards, 369507 frames, score 5, max score 14
# Completed 527 games, 1482 rewards, 371625 frames, score 5, max score 14
# Completed 528 games, 1486 rewards, 372381 frames, score 3, max score 14
# Completed 529 games, 1491 rewards, 373229 frames, score 4, max score 14
# Completed 530 games, 1496 rewards, 374875 frames, score 4, max score 14
# Completed 531 games, 1497 rewards, 375083 frames, score 0, max score 14
# Completed 532 games, 1499 rewards, 375489 frames, score 1, max score 14
# Completed 533 games, 1507 rewards, 378869 frames, score 7, max score 14
# Completed 534 games, 1510 rewards, 379419 frames, score 2, max score 14
# Completed 535 games, 1514 rewards, 380680 frames, score 3, max score 14
# Completed 536 games, 1515 rewards, 380861 frames, score 0, max score 14
# Completed 537 games, 1517 rewards, 381275 frames, score 1, max score 14
# Completed 538 games, 1528 rewards, 384371 frames, score 10, max score 14
# Completed 539 games, 1531 rewards, 384885 frames, score 2, max score 14
# Completed 540 games, 1534 rewards, 385424 frames, score 2, max score 14
# Completed 541 games, 1535 rewards, 385632 frames, score 0, max score 14
# Completed 542 games, 1538 rewards, 386445 frames, score 2, max score 14
# Completed 543 games, 1544 rewards, 387561 frames, score 5, max score 14
# Completed 544 games, 1546 rewards, 387913 frames, score 1, max score 14
# Completed 545 games, 1548 rewards, 388254 frames, score 1, max score 14
# Completed 546 games, 1552 rewards, 388909 frames, score 3, max score 14
# Completed 547 games, 1553 rewards, 389090 frames, score 0, max score 14
# Completed 548 games, 1562 rewards, 391450 frames, score 8, max score 14
# Completed 549 games, 1568 rewards, 393040 frames, score 5, max score 14
# Completed 550 games, 1570 rewards, 393583 frames, score 1, max score 14
# Completed 551 games, 1575 rewards, 394620 frames, score 4, max score 14
# Completed 552 games, 1580 rewards, 395753 frames, score 4, max score 14
# Completed 553 games, 1583 rewards, 397209 frames, score 2, max score 14
# Completed 554 games, 1584 rewards, 397463 frames, score 0, max score 14
# Completed 555 games, 1592 rewards, 402599 frames, score 7, max score 14
# Completed 556 games, 1596 rewards, 404047 frames, score 3, max score 14
# Completed 557 games, 1597 rewards, 404228 frames, score 0, max score 14
# Completed 558 games, 1598 rewards, 404409 frames, score 0, max score 14
# Completed 559 games, 1599 rewards, 404617 frames, score 0, max score 14
# Completed 560 games, 1607 rewards, 406280 frames, score 7, max score 14
# Completed 561 games, 1615 rewards, 407461 frames, score 7, max score 14
# Completed 562 games, 1621 rewards, 408494 frames, score 5, max score 14
# Completed 563 games, 1622 rewards, 408748 frames, score 0, max score 14
# Completed 564 games, 1623 rewards, 408929 frames, score 0, max score 14
# Completed 565 games, 1627 rewards, 410136 frames, score 3, max score 14
# Completed 566 games, 1635 rewards, 411427 frames, score 7, max score 14
# Completed 567 games, 1642 rewards, 413022 frames, score 6, max score 14
# Completed 568 games, 1645 rewards, 413986 frames, score 2, max score 14
# Completed 569 games, 1649 rewards, 415014 frames, score 3, max score 14
# Completed 570 games, 1650 rewards, 415195 frames, score 0, max score 14
# Completed 571 games, 1653 rewards, 415994 frames, score 2, max score 14
# Completed 572 games, 1657 rewards, 416761 frames, score 3, max score 14
# Completed 573 games, 1661 rewards, 417452 frames, score 3, max score 14
# Completed 574 games, 1670 rewards, 419882 frames, score 8, max score 14
# Completed 575 games, 1671 rewards, 420136 frames, score 0, max score 14
# Completed 576 games, 1673 rewards, 420633 frames, score 1, max score 14
# Completed 577 games, 1679 rewards, 421890 frames, score 5, max score 14
# Completed 578 games, 1683 rewards, 422554 frames, score 3, max score 14
# Completed 579 games, 1684 rewards, 422735 frames, score 0, max score 14
# Completed 580 games, 1685 rewards, 422916 frames, score 0, max score 14
# Completed 581 games, 1686 rewards, 423097 frames, score 0, max score 14
# Completed 582 games, 1687 rewards, 423351 frames, score 0, max score 14
# Completed 583 games, 1689 rewards, 423822 frames, score 1, max score 14
# Completed 584 games, 1691 rewards, 424556 frames, score 1, max score 14
# Completed 585 games, 1693 rewards, 425016 frames, score 1, max score 14
# Completed 586 games, 1695 rewards, 425524 frames, score 1, max score 14
# Completed 587 games, 1697 rewards, 425930 frames, score 1, max score 14
# Completed 588 games, 1699 rewards, 426367 frames, score 1, max score 14
# Completed 589 games, 1701 rewards, 426838 frames, score 1, max score 14
# Completed 590 games, 1702 rewards, 427046 frames, score 0, max score 14
# Completed 591 games, 1708 rewards, 428195 frames, score 5, max score 14
# Completed 592 games, 1718 rewards, 431283 frames, score 9, max score 14
# Completed 593 games, 1720 rewards, 431635 frames, score 1, max score 14
# Completed 594 games, 1722 rewards, 432002 frames, score 1, max score 14
# Completed 595 games, 1725 rewards, 432909 frames, score 2, max score 14
# Completed 596 games, 1727 rewards, 433443 frames, score 1, max score 14
# Completed 597 games, 1732 rewards, 434356 frames, score 4, max score 14
# Completed 598 games, 1735 rewards, 435063 frames, score 2, max score 14
# Completed 599 games, 1736 rewards, 435244 frames, score 0, max score 14
# Completed 600 games, 1738 rewards, 435636 frames, score 1, max score 14
# Completed 601 games, 1740 rewards, 436370 frames, score 1, max score 14
# Completed 602 games, 1741 rewards, 436624 frames, score 0, max score 14
# Completed 603 games, 1743 rewards, 437061 frames, score 1, max score 14
# Completed 604 games, 1752 rewards, 441140 frames, score 8, max score 14
# Completed 605 games, 1760 rewards, 442749 frames, score 7, max score 14
# Completed 606 games, 1765 rewards, 443801 frames, score 4, max score 14
# Completed 607 games, 1770 rewards, 445089 frames, score 4, max score 14
# Completed 608 games, 1775 rewards, 446023 frames, score 4, max score 14
# Completed 609 games, 1784 rewards, 448464 frames, score 8, max score 14
# Completed 610 games, 1793 rewards, 450578 frames, score 8, max score 14
# Completed 611 games, 1798 rewards, 451454 frames, score 4, max score 14
# Completed 612 games, 1799 rewards, 451662 frames, score 0, max score 14
# Completed 613 games, 1800 rewards, 451843 frames, score 0, max score 14
# Completed 614 games, 1802 rewards, 452280 frames, score 1, max score 14
# Completed 615 games, 1803 rewards, 452534 frames, score 0, max score 14
# Completed 616 games, 1805 rewards, 453110 frames, score 1, max score 14
# Completed 617 games, 1806 rewards, 453291 frames, score 0, max score 14
# Completed 618 games, 1808 rewards, 453788 frames, score 1, max score 14
# Completed 619 games, 1813 rewards, 454969 frames, score 4, max score 14
# Completed 620 games, 1815 rewards, 455520 frames, score 1, max score 14
# Completed 621 games, 1817 rewards, 455914 frames, score 1, max score 14
# Completed 622 games, 1820 rewards, 456538 frames, score 2, max score 14
# Completed 623 games, 1827 rewards, 457933 frames, score 6, max score 14
# Completed 624 games, 1828 rewards, 458187 frames, score 0, max score 14
# Completed 625 games, 1830 rewards, 458650 frames, score 1, max score 14
# Completed 626 games, 1836 rewards, 460008 frames, score 5, max score 14
# Completed 627 games, 1839 rewards, 460673 frames, score 2, max score 14
# Completed 628 games, 1840 rewards, 460927 frames, score 0, max score 14
# Completed 629 games, 1842 rewards, 461341 frames, score 1, max score 14
# Completed 630 games, 1843 rewards, 461549 frames, score 0, max score 14
# Completed 631 games, 1849 rewards, 463297 frames, score 5, max score 14
# Completed 632 games, 1851 rewards, 463649 frames, score 1, max score 14
# Completed 633 games, 1858 rewards, 464947 frames, score 6, max score 14
# Completed 634 games, 1860 rewards, 465330 frames, score 1, max score 14
# Completed 635 games, 1865 rewards, 466184 frames, score 4, max score 14
# Completed 636 games, 1877 rewards, 472253 frames, score 11, max score 14
# Completed 637 games, 1880 rewards, 472767 frames, score 2, max score 14
# Completed 638 games, 1885 rewards, 473738 frames, score 4, max score 14
# Completed 639 games, 1890 rewards, 475306 frames, score 4, max score 14
# Completed 640 games, 1893 rewards, 475841 frames, score 2, max score 14
# Completed 641 games, 1902 rewards, 477545 frames, score 8, max score 14
# Completed 642 games, 1908 rewards, 478910 frames, score 5, max score 14
# Completed 643 games, 1911 rewards, 479447 frames, score 2, max score 14
# Completed 644 games, 1912 rewards, 479628 frames, score 0, max score 14
# Completed 645 games, 1914 rewards, 480140 frames, score 1, max score 14
# Completed 646 games, 1915 rewards, 480321 frames, score 0, max score 14
# Completed 647 games, 1918 rewards, 481028 frames, score 2, max score 14
# Completed 648 games, 1938 rewards, 493579 frames, score 19, max score 19
# Completed 649 games, 1947 rewards, 498638 frames, score 8, max score 19
# Completed 650 games, 1953 rewards, 499908 frames, score 5, max score 19
# Completed 651 games, 1956 rewards, 500447 frames, score 2, max score 19
# Completed 652 games, 1958 rewards, 500998 frames, score 1, max score 19
# Completed 653 games, 1964 rewards, 502305 frames, score 5, max score 19
# Completed 654 games, 1967 rewards, 503063 frames, score 2, max score 19
# Completed 655 games, 1968 rewards, 503317 frames, score 0, max score 19
# Completed 656 games, 1969 rewards, 503498 frames, score 0, max score 19
# Completed 657 games, 1973 rewards, 505054 frames, score 3, max score 19
# Completed 658 games, 1976 rewards, 505656 frames, score 2, max score 19
# Completed 659 games, 1979 rewards, 506307 frames, score 2, max score 19
# Completed 660 games, 1981 rewards, 506674 frames, score 1, max score 19
# Completed 661 games, 1985 rewards, 507637 frames, score 3, max score 19
# Completed 662 games, 1986 rewards, 507818 frames, score 0, max score 19
# Completed 663 games, 1991 rewards, 508982 frames, score 4, max score 19
# Completed 664 games, 1993 rewards, 509533 frames, score 1, max score 19
# Completed 665 games, 1998 rewards, 510328 frames, score 4, max score 19
# Completed 666 games, 2001 rewards, 510819 frames, score 2, max score 19
# Completed 667 games, 2008 rewards, 512206 frames, score 6, max score 19
# Completed 668 games, 2009 rewards, 512414 frames, score 0, max score 19
# Completed 669 games, 2012 rewards, 513266 frames, score 2, max score 19
# Completed 670 games, 2018 rewards, 514791 frames, score 5, max score 19
# Completed 671 games, 2020 rewards, 515143 frames, score 1, max score 19
# Completed 672 games, 2023 rewards, 515710 frames, score 2, max score 19
# Completed 673 games, 2026 rewards, 516236 frames, score 2, max score 19
# Completed 674 games, 2027 rewards, 516417 frames, score 0, max score 19
# Completed 675 games, 2029 rewards, 516968 frames, score 1, max score 19
# ...
# Completed 4795 games, 60968 rewards, 14194545 frames, score 2, max score 360
# Completed 4796 games, 60969 rewards, 14194726 frames, score 0, max score 360
# Completed 4797 games, 60971 rewards, 14195078 frames, score 1, max score 360
# Completed 4798 games, 60977 rewards, 14196380 frames, score 5, max score 360
# Completed 4799 games, 61003 rewards, 14205174 frames, score 25, max score 360
# Completed 4800 games, 61011 rewards, 14206629 frames, score 7, max score 360
# Completed 4801 games, 61028 rewards, 14209420 frames, score 16, max score 360
# Completed 4802 games, 61045 rewards, 14212142 frames, score 16, max score 360
# Completed 4803 games, 61058 rewards, 14214092 frames, score 12, max score 360
# Completed 4804 games, 61064 rewards, 14215361 frames, score 5, max score 360
# Completed 4805 games, 61066 rewards, 14215729 frames, score 1, max score 360
# Completed 4806 games, 61084 rewards, 14219419 frames, score 17, max score 360
# Completed 4807 games, 61090 rewards, 14220432 frames, score 5, max score 360
# Completed 4808 games, 61103 rewards, 14226266 frames, score 12, max score 360
# Completed 4809 games, 61114 rewards, 14228044 frames, score 10, max score 360
# Completed 4810 games, 61115 rewards, 14228252 frames, score 0, max score 360
# Completed 4811 games, 61121 rewards, 14231009 frames, score 5, max score 360
# Completed 4812 games, 61130 rewards, 14233072 frames, score 8, max score 360
# Completed 4813 games, 61136 rewards, 14234352 frames, score 5, max score 360
# Completed 4814 games, 61151 rewards, 14241373 frames, score 14, max score 360
# Completed 4815 games, 61153 rewards, 14241975 frames, score 1, max score 360
# Completed 4816 games, 61162 rewards, 14243521 frames, score 8, max score 360
# Completed 4817 games, 61164 rewards, 14244440 frames, score 1, max score 360
# Completed 4818 games, 61165 rewards, 14244621 frames, score 0, max score 360
# Completed 4819 games, 61166 rewards, 14244829 frames, score 0, max score 360
# Completed 4820 games, 61168 rewards, 14245266 frames, score 1, max score 360
# Completed 4821 games, 61178 rewards, 14247479 frames, score 9, max score 360
# Completed 4822 games, 61191 rewards, 14252392 frames, score 12, max score 360
# Completed 4823 games, 61205 rewards, 14254858 frames, score 13, max score 360
# Completed 4824 games, 61216 rewards, 14256516 frames, score 10, max score 360
# Completed 4825 games, 61218 rewards, 14256944 frames, score 1, max score 360
# Completed 4826 games, 61227 rewards, 14259035 frames, score 8, max score 360
# Completed 4827 games, 61229 rewards, 14259569 frames, score 1, max score 360
# Completed 4828 games, 61230 rewards, 14259750 frames, score 0, max score 360
# Completed 4829 games, 61251 rewards, 14270802 frames, score 20, max score 360
# Completed 4830 games, 61267 rewards, 14273216 frames, score 15, max score 360
# Completed 4831 games, 61277 rewards, 14278226 frames, score 9, max score 360
# Completed 4832 games, 61280 rewards, 14278879 frames, score 2, max score 360
# Completed 4833 games, 61285 rewards, 14279788 frames, score 4, max score 360
# Completed 4834 games, 61288 rewards, 14280289 frames, score 2, max score 360
# Completed 4835 games, 61299 rewards, 14282301 frames, score 10, max score 360
# Completed 4836 games, 61306 rewards, 14283693 frames, score 6, max score 360
# Completed 4837 games, 61323 rewards, 14288427 frames, score 16, max score 360
# Completed 4838 games, 61325 rewards, 14288779 frames, score 1, max score 360
# Completed 4839 games, 61331 rewards, 14290214 frames, score 5, max score 360
# Completed 4840 games, 61346 rewards, 14294643 frames, score 14, max score 360
# Completed 4841 games, 61353 rewards, 14295982 frames, score 6, max score 360
# Completed 4842 games, 61355 rewards, 14296572 frames, score 1, max score 360
# Completed 4843 games, 61360 rewards, 14298196 frames, score 4, max score 360
# Completed 4844 games, 61363 rewards, 14298903 frames, score 2, max score 360
# Completed 4845 games, 61378 rewards, 14301281 frames, score 14, max score 360
# Completed 4846 games, 61388 rewards, 14303167 frames, score 9, max score 360
# Completed 4847 games, 61395 rewards, 14304312 frames, score 6, max score 360
# Completed 4848 games, 61407 rewards, 14306088 frames, score 11, max score 360
# Completed 4849 games, 61415 rewards, 14311207 frames, score 7, max score 360
# Completed 4850 games, 61417 rewards, 14311686 frames, score 1, max score 360
# Completed 4851 games, 61445 rewards, 14318826 frames, score 27, max score 360
# Completed 4852 games, 61477 rewards, 14326738 frames, score 31, max score 360
# Completed 4853 games, 61480 rewards, 14327539 frames, score 2, max score 360
# Completed 4854 games, 61497 rewards, 14330344 frames, score 16, max score 360
# Completed 4855 games, 61510 rewards, 14332995 frames, score 12, max score 360
# Completed 4856 games, 61521 rewards, 14334924 frames, score 10, max score 360
# Completed 4857 games, 61535 rewards, 14339141 frames, score 13, max score 360
# Completed 4858 games, 61545 rewards, 14341061 frames, score 9, max score 360
# Completed 4859 games, 61573 rewards, 14362837 frames, score 27, max score 360
# Completed 4860 games, 61590 rewards, 14365904 frames, score 16, max score 360
# Completed 4861 games, 61595 rewards, 14366733 frames, score 4, max score 360
# Completed 4862 games, 61598 rewards, 14367239 frames, score 2, max score 360
# Completed 4863 games, 61605 rewards, 14368515 frames, score 6, max score 360
# Completed 4864 games, 61615 rewards, 14370317 frames, score 9, max score 360
# Completed 4865 games, 61641 rewards, 14374340 frames, score 25, max score 360
# Completed 4866 games, 61647 rewards, 14375401 frames, score 5, max score 360
# Completed 4867 games, 61674 rewards, 14385262 frames, score 26, max score 360
# Completed 4868 games, 61684 rewards, 14388191 frames, score 9, max score 360
# Completed 4869 games, 61691 rewards, 14389736 frames, score 6, max score 360
# Completed 4870 games, 61697 rewards, 14390868 frames, score 5, max score 360
# Completed 4871 games, 61700 rewards, 14391432 frames, score 2, max score 360
# Completed 4872 games, 61703 rewards, 14391928 frames, score 2, max score 360
# Completed 4873 games, 61709 rewards, 14392969 frames, score 5, max score 360
# Completed 4874 games, 61727 rewards, 14403122 frames, score 17, max score 360
# Completed 4875 games, 61740 rewards, 14405104 frames, score 12, max score 360
# Completed 4876 games, 61746 rewards, 14407580 frames, score 5, max score 360
# Completed 4877 games, 61751 rewards, 14408690 frames, score 4, max score 360
# Completed 4878 games, 61753 rewards, 14409031 frames, score 1, max score 360
# Completed 4879 games, 61758 rewards, 14410124 frames, score 4, max score 360
# Completed 4880 games, 61776 rewards, 14418109 frames, score 17, max score 360
# Completed 4881 games, 61797 rewards, 14421361 frames, score 20, max score 360
# Completed 4882 games, 61827 rewards, 14430265 frames, score 29, max score 360
# Completed 4883 games, 61831 rewards, 14431074 frames, score 3, max score 360
# Completed 4884 games, 61843 rewards, 14434579 frames, score 11, max score 360
# Completed 4885 games, 61851 rewards, 14436984 frames, score 7, max score 360
# Completed 4886 games, 61854 rewards, 14437500 frames, score 2, max score 360
# Completed 4887 games, 61863 rewards, 14439418 frames, score 8, max score 360
# Completed 4888 games, 61881 rewards, 14444354 frames, score 17, max score 360
# Completed 4889 games, 61886 rewards, 14445213 frames, score 4, max score 360
# Completed 4890 games, 61911 rewards, 14451719 frames, score 24, max score 360
# Completed 4891 games, 61919 rewards, 14453601 frames, score 7, max score 360
# Completed 4892 games, 61929 rewards, 14455093 frames, score 9, max score 360
# Completed 4893 games, 61936 rewards, 14457377 frames, score 6, max score 360
# Completed 4894 games, 61942 rewards, 14458610 frames, score 5, max score 360
# Completed 4895 games, 61959 rewards, 14461535 frames, score 16, max score 360
# Completed 4896 games, 61967 rewards, 14462740 frames, score 7, max score 360
# Completed 4897 games, 61973 rewards, 14463793 frames, score 5, max score 360
# Completed 4898 games, 61982 rewards, 14465312 frames, score 8, max score 360
# Completed 4899 games, 61984 rewards, 14465680 frames, score 1, max score 360
# Completed 4900 games, 61993 rewards, 14469390 frames, score 8, max score 360
# Completed 4901 games, 62002 rewards, 14471215 frames, score 8, max score 360
# Completed 4902 games, 62015 rewards, 14473187 frames, score 12, max score 360
# Completed 4903 games, 62033 rewards, 14476550 frames, score 17, max score 360
# Completed 4904 games, 62044 rewards, 14479324 frames, score 10, max score 360
# Completed 4905 games, 62068 rewards, 14484171 frames, score 23, max score 360
# Completed 4906 games, 62071 rewards, 14484937 frames, score 2, max score 360
# Completed 4907 games, 62121 rewards, 14494263 frames, score 49, max score 360
# Completed 4908 games, 62137 rewards, 14497968 frames, score 15, max score 360
# Completed 4909 games, 62138 rewards, 14498149 frames, score 0, max score 360
# Completed 4910 games, 62141 rewards, 14498751 frames, score 2, max score 360
# Completed 4911 games, 62177 rewards, 14516287 frames, score 35, max score 360
# Completed 4912 games, 62181 rewards, 14517416 frames, score 3, max score 360
# Completed 4913 games, 62201 rewards, 14521294 frames, score 19, max score 360
# Completed 4914 games, 62242 rewards, 14536706 frames, score 40, max score 360
# Completed 4915 games, 62247 rewards, 14537694 frames, score 4, max score 360
# Completed 4916 games, 62274 rewards, 14542684 frames, score 26, max score 360
# Completed 4917 games, 62280 rewards, 14543763 frames, score 5, max score 360
# Completed 4918 games, 62282 rewards, 14544161 frames, score 1, max score 360
# Completed 4919 games, 62288 rewards, 14545365 frames, score 5, max score 360
# Completed 4920 games, 62298 rewards, 14547788 frames, score 9, max score 360
# Completed 4921 games, 62308 rewards, 14550441 frames, score 9, max score 360
# Completed 4922 games, 62325 rewards, 14553167 frames, score 16, max score 360
# Completed 4923 games, 62340 rewards, 14555588 frames, score 14, max score 360
# Completed 4924 games, 62352 rewards, 14557778 frames, score 11, max score 360
# Completed 4925 games, 62357 rewards, 14558664 frames, score 4, max score 360
# Completed 4926 games, 62377 rewards, 14565152 frames, score 19, max score 360
# Completed 4927 games, 62384 rewards, 14566805 frames, score 6, max score 360
# Completed 4928 games, 62419 rewards, 14572635 frames, score 34, max score 360
# Completed 4929 games, 62429 rewards, 14574648 frames, score 9, max score 360
# Completed 4930 games, 62438 rewards, 14576420 frames, score 8, max score 360
# Completed 4931 games, 62471 rewards, 14584382 frames, score 32, max score 360
# Completed 4932 games, 62489 rewards, 14587586 frames, score 17, max score 360
# Completed 4933 games, 62505 rewards, 14590323 frames, score 15, max score 360
# Completed 4934 games, 62510 rewards, 14591112 frames, score 4, max score 360
# Completed 4935 games, 62514 rewards, 14591801 frames, score 3, max score 360
# Completed 4936 games, 62531 rewards, 14594740 frames, score 16, max score 360
# Completed 4937 games, 62542 rewards, 14597292 frames, score 10, max score 360
# Completed 4938 games, 62566 rewards, 14609791 frames, score 23, max score 360
# Completed 4939 games, 62568 rewards, 14610288 frames, score 1, max score 360
# Completed 4940 games, 62575 rewards, 14611395 frames, score 6, max score 360
# Completed 4941 games, 62587 rewards, 14613293 frames, score 11, max score 360
# Completed 4942 games, 62625 rewards, 14620603 frames, score 37, max score 360
# Completed 4943 games, 62638 rewards, 14623236 frames, score 12, max score 360
# Completed 4944 games, 62641 rewards, 14624084 frames, score 2, max score 360
# Completed 4945 games, 62642 rewards, 14624265 frames, score 0, max score 360
# Completed 4946 games, 62648 rewards, 14625223 frames, score 5, max score 360
# Completed 4947 games, 62663 rewards, 14628034 frames, score 14, max score 360
# Completed 4948 games, 62680 rewards, 14633388 frames, score 16, max score 360
# Completed 4949 games, 62699 rewards, 14637874 frames, score 18, max score 360
# Completed 4950 games, 62741 rewards, 14666052 frames, score 41, max score 360
# Completed 4951 games, 62752 rewards, 14668306 frames, score 10, max score 360
# Completed 4952 games, 62756 rewards, 14669038 frames, score 3, max score 360
# Completed 4953 games, 62760 rewards, 14669801 frames, score 3, max score 360
# Completed 4954 games, 62788 rewards, 14680192 frames, score 27, max score 360
# Completed 4955 games, 62801 rewards, 14682961 frames, score 12, max score 360
# Completed 4956 games, 62823 rewards, 14688935 frames, score 21, max score 360
# Completed 4957 games, 62839 rewards, 14691592 frames, score 15, max score 360
# Completed 4958 games, 62878 rewards, 14697787 frames, score 38, max score 360
# Completed 4959 games, 62881 rewards, 14698479 frames, score 2, max score 360
# Completed 4960 games, 62917 rewards, 14708315 frames, score 35, max score 360
# Completed 4961 games, 62929 rewards, 14710712 frames, score 11, max score 360
# Completed 4962 games, 62948 rewards, 14713623 frames, score 18, max score 360
# Completed 4963 games, 62988 rewards, 14719935 frames, score 39, max score 360
# Completed 4964 games, 62993 rewards, 14720874 frames, score 4, max score 360
# Completed 4965 games, 63024 rewards, 14727997 frames, score 30, max score 360
# Completed 4966 games, 63037 rewards, 14731998 frames, score 12, max score 360
# Completed 4967 games, 63045 rewards, 14734097 frames, score 7, max score 360
# Completed 4968 games, 63055 rewards, 14735942 frames, score 9, max score 360
# Completed 4969 games, 63057 rewards, 14736294 frames, score 1, max score 360
# Completed 4970 games, 63074 rewards, 14743842 frames, score 16, max score 360
# Completed 4971 games, 63076 rewards, 14744194 frames, score 1, max score 360
# Completed 4972 games, 63081 rewards, 14746818 frames, score 4, max score 360
# Completed 4973 games, 63099 rewards, 14751355 frames, score 17, max score 360
# Completed 4974 games, 63107 rewards, 14752756 frames, score 7, max score 360
# Completed 4975 games, 63141 rewards, 14760674 frames, score 33, max score 360
# Completed 4976 games, 63146 rewards, 14761539 frames, score 4, max score 360
# Completed 4977 games, 63177 rewards, 14766373 frames, score 30, max score 360
# Completed 4978 games, 63208 rewards, 14784592 frames, score 30, max score 360
# Completed 4979 games, 63209 rewards, 14784773 frames, score 0, max score 360
# Completed 4980 games, 63217 rewards, 14786458 frames, score 7, max score 360
# Completed 4981 games, 63219 rewards, 14786810 frames, score 1, max score 360
# Completed 4982 games, 63234 rewards, 14789930 frames, score 14, max score 360
# Completed 4983 games, 63243 rewards, 14791332 frames, score 8, max score 360
# Completed 4984 games, 63254 rewards, 14794604 frames, score 10, max score 360
# Completed 4985 games, 63260 rewards, 14795861 frames, score 5, max score 360
# Completed 4986 games, 63274 rewards, 14799697 frames, score 13, max score 360
# Completed 4987 games, 63276 rewards, 14800038 frames, score 1, max score 360
# Completed 4988 games, 63308 rewards, 14804889 frames, score 31, max score 360
# Completed 4989 games, 63319 rewards, 14806729 frames, score 10, max score 360
# Completed 4990 games, 63322 rewards, 14807349 frames, score 2, max score 360
# Completed 4991 games, 63326 rewards, 14808074 frames, score 3, max score 360
# Completed 4992 games, 63340 rewards, 14810233 frames, score 13, max score 360
# Completed 4993 games, 63363 rewards, 14816601 frames, score 22, max score 360
# Completed 4994 games, 63373 rewards, 14818238 frames, score 9, max score 360
# Completed 4995 games, 63388 rewards, 14822619 frames, score 14, max score 360
# Completed 4996 games, 63393 rewards, 14823619 frames, score 4, max score 360
# Completed 4997 games, 63400 rewards, 14824724 frames, score 6, max score 360
# Completed 4998 games, 63422 rewards, 14830119 frames, score 21, max score 360
# Completed 4999 games, 63429 rewards, 14832047 frames, score 6, max score 360
# The number of games played was 5000
# The number of video frames was 5000
# The size of each returned Q-matrix was (0,)

# %% [markdown]
# Now let's plot the score, to see if it improved over time.  We will also plot the local average, averaged over 10 consecutive games, to see if that has improved.  Notice that we can use `np.convolve` to compute the local average.
#
# These numbers are really noisy, with a really large maximum.  We will plot `np.log10(1+x)`, rather than x, so that we can better see the average numbers, and ignore the very large noisy spikes.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,9),layout='tight')
ax = [ fig.add_subplot(3,1,x) for x in range(1,4) ]
ax[0].plot(np.arange(0,len(scores)),np.log10(1+np.array(scores)))
ax[0].plot([0,5000],np.log10([7,7]),'k--')
ax[0].set_title('Game scores')
ax[1].plot(np.arange(4991),np.log10(1+np.convolve(np.ones(10)/10,scores,mode='valid')))
ax[1].plot([0,4991],np.log10([7,7]),'k--')
ax[1].set_title('Game scores, average 10 consecutive games')
ax[2].plot(np.arange(0,len(q_achieved)),q_achieved)
ax[2].set_title('Q values of state achieved at each time')
ax[2].set_ylabel('Game number')
# Out:
# Text(0, 0.5, 'Game number')

# %% [markdown]
# Hooray, it has learned!  If you are getting a ten-game average score of better than 6, then you are ready to submit your model for grading.   In order to do that, you need to save the model:

# %%
q_learner.save('trained_model.npz')

# %% [markdown]
# <a id='section9'></a>

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# For extra credit, download the file <a href="mp11_extra.zip">mp11_extra.zip</a>.  The only important file in this package is:
# * `tests/test_extra.py`: this contains extra tests that will evaluate your pre-trained `deep_q` learner, which should be in a file called `trained_model.pkl`.  For full credit, your model should achieve an average score of greater than 20, averaged over 10 consecutive games.
#
# With a quantized lookup table, it's probably not possible to achieve an average score of 20.  With a deep-Q learner, however, it is eminently possible.  In order to do the extra credit, therefore, you should just fill in the part of `submitted.py` that implements the `deep_q` learner, using pytorch to define a model structure, train it, save it, load it, and act on it.  This learner only needs to have five methods: `__init__`, `act`, `learn`, `save`, and `load`:

# %%
importlib.reload(submitted)
help(submitted.deep_q.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst)
#     Create a new deep_q learner.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a deep learning model that will accept
#     (state,action) as input, and estimate Q as the output.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#
#     @return:
#     None

# %%
import pong, importlib, submitted
importlib.reload(submitted)
deep_q_learner=submitted.deep_q(0.05,0.05,0.99,5)
pong_game_deep_q = pong.PongGame(learner=deep_q_learner, visible=False)
scores, q_achieved, q_states = pong_game_deep_q.run(m_games=500, states=[])
deep_q_learner.save('trained_model.pkl')

# %%
help(submitted.deep_q.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     You are free to determine your own exploration/exploitation policy --
#     you don't need to use the epsilon and nfirst provided to you.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %%
help(submitted.deep_q.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Perform one iteration of training on a deep-Q model.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 floats, in the same format as state
#
#     @return:
#     None

# %%
help(submitted.deep_q.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your trained deep-Q model to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
help(submitted.deep_q.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load your deep-Q model from a file.
#     This should load from whatever file format your save function
#     used.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None
